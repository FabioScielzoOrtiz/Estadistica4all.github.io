# %% [markdown]
# # Data Manipulation in Python for R users
#
# ## Indice:
# * [Head and Tail](#1)
# * [Selecting](#2)
# * [Sampling](#3)
# * [Filtering](#4)
# * [Mutate](#5)
# * [Arrange](#6)
# * [Rename](#7)
# * [Gather](#8)
# * [Spread](#9)
# * [Separate](#10)
# * [Unite](#11)
# * [Joins](#12)
# * *  [Inner Join](#13)
# * * [Full Join](#14)
# * * [Left Join](#15)
# * * [Right Join](#16)
# * * [Semi Join](#17)
# * * [Anti Join](#18)
# * * [Union](#19)
# * * [Intersect](#20)
# * * [Difference](#21)
# *  [Concatenate](#22)
# *  [Group and Summarize](#23)
# *  [Other usuful functions ](#24)
#
#
#
# This article is about data manipulation in Python, but it´s made thinking in data manipulation in R. So here we are not going to be focus on data manipulation with Pandas, that is the classic python package for that propose. Instead of that we will use a package inspired in dplyr R package, that´s probably the most used R packages for data manipulation.
#
# `Dfply` is a Python package whose main goal is replicate dplyr R package. There are other Python packages that allows it, as `dplython`, but `Dfply`  is more developed.

# %% [markdown]
# All merits must go to Kiefer Katovich, who is the developer of the `Dfply` package.
#
# Here the repository of the package, on which this article is based:
#
# https://github.com/kieferk/dfply

# %%
import pandas as pd

from IPython.display import display
pd.options.display.max_columns = None

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We can install `dfply` as follows:

# %%
# pip install dfply

# %%
from dfply import *

# %% [markdown]
# We load a data-set with which we will work:

# %% [markdown]
# We will use the following url to obtein the data:
#
# https://raw.githubusercontent.com/FabioScielzoOrtiz/Estadistica4all-blog/main/Data%20Manipulation%20in%20Python/properties_data.csv

# %%
url = 'https://raw.githubusercontent.com/FabioScielzoOrtiz/Estadistica4all-blog/main/Data%20Manipulation%20in%20Python/properties_data.csv'
data = pd.read_csv(url)
data
# Out:
#            id                       neighborhood   latitude  longitude  \
# 0     5528049                      Palm Jumeirah  25.000000  55.138932
# 1     6008529                      Palm Jumeirah  25.106809  55.151201
# 2     6034542               Jumeirah Lake Towers  25.063302  55.137728
# 3     6326063                    Culture Village  25.227295  55.341761
# 4     6356778                      Palm Jumeirah  25.114275  55.139764
# ...       ...                                ...        ...        ...
# 1900  7705450           Mohammed Bin Rashid City  25.176892  55.310712
# 1901  7706287           Mohammed Bin Rashid City  25.166145  55.276684
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  25.206500  55.345056
# 1903  7706591            Jumeirah Village Circle  25.073858  55.229844
# 1904  7706643               Jumeirah Lake Towers  25.079130  55.154713
#
#         price  size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  \
# 0     2700000          1079         2502.32               1                2
# 1     2850000          1582         1801.52               2                2
# 2     1150000          1951          589.44               3                5
# 3     2850000          2020         1410.89               2                3
# 4     1729200           507         3410.65               0                1
# ...       ...           ...             ...             ...              ...
# 1900  1500000          1087         1379.94               2                2
# 1901  1230000           760         1618.42               1                2
# 1902  2900000          1930         1502.59               3                5
# 1903   675000           740          912.16               1                2
# 1904   760887           800          951.11               1                2
#
#      quality  maid_room  unfurnished  balcony  barbecue_area  \
# 0     Medium      False        False     True           True
# 1     Medium      False        False     True          False
# 2     Medium       True         True     True          False
# 3        Low      False         True     True          False
# 4     Medium      False        False    False          False
# ...      ...        ...          ...      ...            ...
# 1900   Ultra      False         True     True           True
# 1901  Medium      False        False     True          False
# 1902  Medium       True         True     True          False
# 1903  Medium      False         True     True          False
# 1904    High      False        False     True           True
#
#       built_in_wardrobes  central_ac  childrens_play_area  childrens_pool  \
# 0                  False        True                 True           False
# 1                   True        True                 True           False
# 2                   True       False                False           False
# 3                  False       False                False           False
# 4                   True        True                False           False
# ...                  ...         ...                  ...             ...
# 1900                True        True                 True            True
# 1901                True        True                 True           False
# 1902               False        True                 True           False
# 1903                True        True                 True           False
# 1904                True        True                 True            True
#
#       concierge  covered_parking  kitchen_appliances  lobby_in_building  \
# 0          True            False                True              False
# 1         False            False               False              False
# 2         False             True               False              False
# 3          True             True               False              False
# 4         False             True                True              False
# ...         ...              ...                 ...                ...
# 1900       True             True                True               True
# 1901       True            False                True              False
# 1902      False            False               False              False
# 1903      False             True                True              False
# 1904       True             True                True               True
#
#       maid_service  networked  pets_allowed  private_garden  private_gym  \
# 0            False      False          True           False        False
# 1            False      False         False           False        False
# 2            False      False         False           False        False
# 3            False      False          True           False        False
# 4            False       True         False           False        False
# ...            ...        ...           ...             ...          ...
# 1900          True       True          True           False        False
# 1901         False      False         False           False        False
# 1902         False      False          True           False        False
# 1903         False      False         False            True        False
# 1904         False      False         False           False        False
#
#       private_jacuzzi  private_pool  security  shared_gym  shared_pool  \
# 0               False         False     False        True        False
# 1               False         False     False        True         True
# 2                True         False      True        True         True
# 3               False         False     False       False        False
# 4               False         False      True        True         True
# ...               ...           ...       ...         ...          ...
# 1900            False         False      True        True         True
# 1901            False         False     False        True         True
# 1902            False         False     False       False         True
# 1903            False         False      True        True         True
# 1904            False         False      True        True         True
#
#       shared_spa  study  vastu_compliant  view_of_landmark  view_of_water  \
# 0          False  False            False             False           True
# 1          False  False            False             False           True
# 2          False  False            False              True           True
# 3          False  False            False             False          False
# 4           True  False            False              True           True
# ...          ...    ...              ...               ...            ...
# 1900        True   True             True              True           True
# 1901       False  False            False             False           True
# 1902       False  False            False             False          False
# 1903       False  False            False             False           True
# 1904        True  False            False             False           True
#
#       walk_in_closet
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
# ...              ...
# 1900            True
# 1901            True
# 1902           False
# 1903            True
# 1904           False
#
# [1905 rows x 38 columns]

# %% [markdown]
# ## Head and Tail <a class="anchor" id="1"></a>

# %% [markdown]
# We can see the head of the data-set:

# %%
data >> head(5)
# Out:
#         id          neighborhood   latitude  longitude    price  size_in_sqft  \
# 0  5528049         Palm Jumeirah  25.000000  55.138932  2700000          1079
# 1  6008529         Palm Jumeirah  25.106809  55.151201  2850000          1582
# 2  6034542  Jumeirah Lake Towers  25.063302  55.137728  1150000          1951
# 3  6326063       Culture Village  25.227295  55.341761  2850000          2020
# 4  6356778         Palm Jumeirah  25.114275  55.139764  1729200           507
#
#    price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 0         2502.32               1                2  Medium      False
# 1         1801.52               2                2  Medium      False
# 2          589.44               3                5  Medium       True
# 3         1410.89               2                3     Low      False
# 4         3410.65               0                1  Medium      False
#
#    unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# 0        False     True           True               False        True
# 1        False     True          False                True        True
# 2         True     True          False                True       False
# 3         True     True          False               False       False
# 4        False    False          False                True        True
#
#    childrens_play_area  childrens_pool  concierge  covered_parking  \
# 0                 True           False       True            False
# 1                 True           False      False            False
# 2                False           False      False             True
# 3                False           False       True             True
# 4                False           False      False             True
#
#    kitchen_appliances  lobby_in_building  maid_service  networked  \
# 0                True              False         False      False
# 1               False              False         False      False
# 2               False              False         False      False
# 3               False              False         False      False
# 4                True              False         False       True
#
#    pets_allowed  private_garden  private_gym  private_jacuzzi  private_pool  \
# 0          True           False        False            False         False
# 1         False           False        False            False         False
# 2         False           False        False             True         False
# 3          True           False        False            False         False
# 4         False           False        False            False         False
#
#    security  shared_gym  shared_pool  shared_spa  study  vastu_compliant  \
# 0     False        True        False       False  False            False
# 1     False        True         True       False  False            False
# 2      True        True         True       False  False            False
# 3     False       False        False       False  False            False
# 4      True        True         True        True  False            False
#
#    view_of_landmark  view_of_water  walk_in_closet
# 0             False           True           False
# 1             False           True           False
# 2              True           True            True
# 3             False          False           False
# 4              True           True           False

# %% [markdown]
# Also We can see the tail of the data-set:

# %%
data >> tail(5)
# Out:
#            id                       neighborhood   latitude  longitude  \
# 1900  7705450           Mohammed Bin Rashid City  25.176892  55.310712
# 1901  7706287           Mohammed Bin Rashid City  25.166145  55.276684
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  25.206500  55.345056
# 1903  7706591            Jumeirah Village Circle  25.073858  55.229844
# 1904  7706643               Jumeirah Lake Towers  25.079130  55.154713
#
#         price  size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  \
# 1900  1500000          1087         1379.94               2                2
# 1901  1230000           760         1618.42               1                2
# 1902  2900000          1930         1502.59               3                5
# 1903   675000           740          912.16               1                2
# 1904   760887           800          951.11               1                2
#
#      quality  maid_room  unfurnished  balcony  barbecue_area  \
# 1900   Ultra      False         True     True           True
# 1901  Medium      False        False     True          False
# 1902  Medium       True         True     True          False
# 1903  Medium      False         True     True          False
# 1904    High      False        False     True           True
#
#       built_in_wardrobes  central_ac  childrens_play_area  childrens_pool  \
# 1900                True        True                 True            True
# 1901                True        True                 True           False
# 1902               False        True                 True           False
# 1903                True        True                 True           False
# 1904                True        True                 True            True
#
#       concierge  covered_parking  kitchen_appliances  lobby_in_building  \
# 1900       True             True                True               True
# 1901       True            False                True              False
# 1902      False            False               False              False
# 1903      False             True                True              False
# 1904       True             True                True               True
#
#       maid_service  networked  pets_allowed  private_garden  private_gym  \
# 1900          True       True          True           False        False
# 1901         False      False         False           False        False
# 1902         False      False          True           False        False
# 1903         False      False         False            True        False
# 1904         False      False         False           False        False
#
#       private_jacuzzi  private_pool  security  shared_gym  shared_pool  \
# 1900            False         False      True        True         True
# 1901            False         False     False        True         True
# 1902            False         False     False       False         True
# 1903            False         False      True        True         True
# 1904            False         False      True        True         True
#
#       shared_spa  study  vastu_compliant  view_of_landmark  view_of_water  \
# 1900        True   True             True              True           True
# 1901       False  False            False             False           True
# 1902       False  False            False             False          False
# 1903       False  False            False             False           True
# 1904        True  False            False             False           True
#
#       walk_in_closet
# 1900            True
# 1901            True
# 1902           False
# 1903            True
# 1904           False

# %% [markdown]
# ## Selecting <a class="anchor" id="2"></a>

# %% [markdown]
# Selecting columns of the data-set:

# %%
data >> select(X.price , X.size_in_sqft, X.no_of_bedrooms , X.no_of_bathrooms)
# Out:
#         price  size_in_sqft  no_of_bedrooms  no_of_bathrooms
# 0     2700000          1079               1                2
# 1     2850000          1582               2                2
# 2     1150000          1951               3                5
# 3     2850000          2020               2                3
# 4     1729200           507               0                1
# ...       ...           ...             ...              ...
# 1900  1500000          1087               2                2
# 1901  1230000           760               1                2
# 1902  2900000          1930               3                5
# 1903   675000           740               1                2
# 1904   760887           800               1                2
#
# [1905 rows x 4 columns]

# %%
data >> select( 4, 7, 8)
# Out:
#         price  no_of_bedrooms  no_of_bathrooms
# 0     2700000               1                2
# 1     2850000               2                2
# 2     1150000               3                5
# 3     2850000               2                3
# 4     1729200               0                1
# ...       ...             ...              ...
# 1900  1500000               2                2
# 1901  1230000               1                2
# 1902  2900000               3                5
# 1903   675000               1                2
# 1904   760887               1                2
#
# [1905 rows x 3 columns]

# %% [markdown]
# We can select all the columns (variables) that are different to some:

# %%
data >> select( ~X.neighborhood , ~X.id )
# Out:
#        latitude  longitude    price  size_in_sqft  price_per_sqft  \
# 0     25.000000  55.138932  2700000          1079         2502.32
# 1     25.106809  55.151201  2850000          1582         1801.52
# 2     25.063302  55.137728  1150000          1951          589.44
# 3     25.227295  55.341761  2850000          2020         1410.89
# 4     25.114275  55.139764  1729200           507         3410.65
# ...         ...        ...      ...           ...             ...
# 1900  25.176892  55.310712  1500000          1087         1379.94
# 1901  25.166145  55.276684  1230000           760         1618.42
# 1902  25.206500  55.345056  2900000          1930         1502.59
# 1903  25.073858  55.229844   675000           740          912.16
# 1904  25.079130  55.154713   760887           800          951.11
#
#       no_of_bedrooms  no_of_bathrooms quality  maid_room  unfurnished  \
# 0                  1                2  Medium      False        False
# 1                  2                2  Medium      False        False
# 2                  3                5  Medium       True         True
# 3                  2                3     Low      False         True
# 4                  0                1  Medium      False        False
# ...              ...              ...     ...        ...          ...
# 1900               2                2   Ultra      False         True
# 1901               1                2  Medium      False        False
# 1902               3                5  Medium       True         True
# 1903               1                2  Medium      False         True
# 1904               1                2    High      False        False
#
#       balcony  barbecue_area  built_in_wardrobes  central_ac  \
# 0        True           True               False        True
# 1        True          False                True        True
# 2        True          False                True       False
# 3        True          False               False       False
# 4       False          False                True        True
# ...       ...            ...                 ...         ...
# 1900     True           True                True        True
# 1901     True          False                True        True
# 1902     True          False               False        True
# 1903     True          False                True        True
# 1904     True           True                True        True
#
#       childrens_play_area  childrens_pool  concierge  covered_parking  \
# 0                    True           False       True            False
# 1                    True           False      False            False
# 2                   False           False      False             True
# 3                   False           False       True             True
# 4                   False           False      False             True
# ...                   ...             ...        ...              ...
# 1900                 True            True       True             True
# 1901                 True           False       True            False
# 1902                 True           False      False            False
# 1903                 True           False      False             True
# 1904                 True            True       True             True
#
#       kitchen_appliances  lobby_in_building  maid_service  networked  \
# 0                   True              False         False      False
# 1                  False              False         False      False
# 2                  False              False         False      False
# 3                  False              False         False      False
# 4                   True              False         False       True
# ...                  ...                ...           ...        ...
# 1900                True               True          True       True
# 1901                True              False         False      False
# 1902               False              False         False      False
# 1903                True              False         False      False
# 1904                True               True         False      False
#
#       pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 0             True           False        False            False
# 1            False           False        False            False
# 2            False           False        False             True
# 3             True           False        False            False
# 4            False           False        False            False
# ...            ...             ...          ...              ...
# 1900          True           False        False            False
# 1901         False           False        False            False
# 1902          True           False        False            False
# 1903         False            True        False            False
# 1904         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 0            False     False        True        False       False  False
# 1            False     False        True         True       False  False
# 2            False      True        True         True       False  False
# 3            False     False       False        False       False  False
# 4            False      True        True         True        True  False
# ...            ...       ...         ...          ...         ...    ...
# 1900         False      True        True         True        True   True
# 1901         False     False        True         True       False  False
# 1902         False     False       False         True       False  False
# 1903         False      True        True         True       False  False
# 1904         False      True        True         True        True  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 0               False             False           True           False
# 1               False             False           True           False
# 2               False              True           True            True
# 3               False             False          False           False
# 4               False              True           True           False
# ...               ...               ...            ...             ...
# 1900             True              True           True            True
# 1901            False             False           True            True
# 1902            False             False          False           False
# 1903            False             False           True            True
# 1904            False             False           True           False
#
# [1905 rows x 36 columns]

# %% [markdown]
# Note that if you are going to use the inversion operator, you must place it prior to the symbolic X

# %%
data >> select(starts_with('p')) >> head(5)
# Out:
#      price  price_per_sqft  pets_allowed  private_garden  private_gym  \
# 0  2700000         2502.32          True           False        False
# 1  2850000         1801.52         False           False        False
# 2  1150000          589.44         False           False        False
# 3  2850000         1410.89          True           False        False
# 4  1729200         3410.65         False           False        False
#
#    private_jacuzzi  private_pool
# 0            False         False
# 1            False         False
# 2             True         False
# 3            False         False
# 4            False         False

# %% [markdown]
# Now we are going to see more specifical functions to select columns.

# %%
data >> select( ~ starts_with('p')) >> head(5)
# Out:
#         id          neighborhood   latitude  longitude  size_in_sqft  \
# 0  5528049         Palm Jumeirah  25.000000  55.138932          1079
# 1  6008529         Palm Jumeirah  25.106809  55.151201          1582
# 2  6034542  Jumeirah Lake Towers  25.063302  55.137728          1951
# 3  6326063       Culture Village  25.227295  55.341761          2020
# 4  6356778         Palm Jumeirah  25.114275  55.139764           507
#
#    no_of_bedrooms  no_of_bathrooms quality  maid_room  unfurnished  balcony  \
# 0               1                2  Medium      False        False     True
# 1               2                2  Medium      False        False     True
# 2               3                5  Medium       True         True     True
# 3               2                3     Low      False         True     True
# 4               0                1  Medium      False        False    False
#
#    barbecue_area  built_in_wardrobes  central_ac  childrens_play_area  \
# 0           True               False        True                 True
# 1          False                True        True                 True
# 2          False                True       False                False
# 3          False               False       False                False
# 4          False                True        True                False
#
#    childrens_pool  concierge  covered_parking  kitchen_appliances  \
# 0           False       True            False                True
# 1           False      False            False               False
# 2           False      False             True               False
# 3           False       True             True               False
# 4           False      False             True                True
#
#    lobby_in_building  maid_service  networked  security  shared_gym  \
# 0              False         False      False     False        True
# 1              False         False      False     False        True
# 2              False         False      False      True        True
# 3              False         False      False     False       False
# 4              False         False       True      True        True
#
#    shared_pool  shared_spa  study  vastu_compliant  view_of_landmark  \
# 0        False       False  False            False             False
# 1         True       False  False            False             False
# 2         True       False  False            False              True
# 3        False       False  False            False             False
# 4         True        True  False            False              True
#
#    view_of_water  walk_in_closet
# 0           True           False
# 1           True           False
# 2           True            True
# 3          False           False
# 4           True           False

# %%
data >> select( ends_with('e')) >> head(5)
# Out:
#     latitude  longitude    price  concierge  maid_service
# 0  25.000000  55.138932  2700000       True         False
# 1  25.106809  55.151201  2850000      False         False
# 2  25.063302  55.137728  1150000      False         False
# 3  25.227295  55.341761  2850000       True         False
# 4  25.114275  55.139764  1729200      False         False

# %%
data >> select(contains('of'))
# Out:
#       no_of_bedrooms  no_of_bathrooms  view_of_landmark  view_of_water
# 0                  1                2             False           True
# 1                  2                2             False           True
# 2                  3                5              True           True
# 3                  2                3             False          False
# 4                  0                1              True           True
# ...              ...              ...               ...            ...
# 1900               2                2              True           True
# 1901               1                2             False           True
# 1902               3                5             False          False
# 1903               1                2             False           True
# 1904               1                2             False           True
#
# [1905 rows x 4 columns]

# %%
data >> select(columns_between( X.latitude , X.size_in_sqft , inclusive=True))
# Out:
#        latitude  longitude    price  size_in_sqft
# 0     25.000000  55.138932  2700000          1079
# 1     25.106809  55.151201  2850000          1582
# 2     25.063302  55.137728  1150000          1951
# 3     25.227295  55.341761  2850000          2020
# 4     25.114275  55.139764  1729200           507
# ...         ...        ...      ...           ...
# 1900  25.176892  55.310712  1500000          1087
# 1901  25.166145  55.276684  1230000           760
# 1902  25.206500  55.345056  2900000          1930
# 1903  25.073858  55.229844   675000           740
# 1904  25.079130  55.154713   760887           800
#
# [1905 rows x 4 columns]

# %%
data >> select( ~ columns_between( X.latitude , X.size_in_sqft , inclusive=True))
# Out:
#            id                       neighborhood  price_per_sqft  \
# 0     5528049                      Palm Jumeirah         2502.32
# 1     6008529                      Palm Jumeirah         1801.52
# 2     6034542               Jumeirah Lake Towers          589.44
# 3     6326063                    Culture Village         1410.89
# 4     6356778                      Palm Jumeirah         3410.65
# ...       ...                                ...             ...
# 1900  7705450           Mohammed Bin Rashid City         1379.94
# 1901  7706287           Mohammed Bin Rashid City         1618.42
# 1902  7706389  Dubai Creek Harbour (The Lagoons)         1502.59
# 1903  7706591            Jumeirah Village Circle          912.16
# 1904  7706643               Jumeirah Lake Towers          951.11
#
#       no_of_bedrooms  no_of_bathrooms quality  maid_room  unfurnished  \
# 0                  1                2  Medium      False        False
# 1                  2                2  Medium      False        False
# 2                  3                5  Medium       True         True
# 3                  2                3     Low      False         True
# 4                  0                1  Medium      False        False
# ...              ...              ...     ...        ...          ...
# 1900               2                2   Ultra      False         True
# 1901               1                2  Medium      False        False
# 1902               3                5  Medium       True         True
# 1903               1                2  Medium      False         True
# 1904               1                2    High      False        False
#
#       balcony  barbecue_area  built_in_wardrobes  central_ac  \
# 0        True           True               False        True
# 1        True          False                True        True
# 2        True          False                True       False
# 3        True          False               False       False
# 4       False          False                True        True
# ...       ...            ...                 ...         ...
# 1900     True           True                True        True
# 1901     True          False                True        True
# 1902     True          False               False        True
# 1903     True          False                True        True
# 1904     True           True                True        True
#
#       childrens_play_area  childrens_pool  concierge  covered_parking  \
# 0                    True           False       True            False
# 1                    True           False      False            False
# 2                   False           False      False             True
# 3                   False           False       True             True
# 4                   False           False      False             True
# ...                   ...             ...        ...              ...
# 1900                 True            True       True             True
# 1901                 True           False       True            False
# 1902                 True           False      False            False
# 1903                 True           False      False             True
# 1904                 True            True       True             True
#
#       kitchen_appliances  lobby_in_building  maid_service  networked  \
# 0                   True              False         False      False
# 1                  False              False         False      False
# 2                  False              False         False      False
# 3                  False              False         False      False
# 4                   True              False         False       True
# ...                  ...                ...           ...        ...
# 1900                True               True          True       True
# 1901                True              False         False      False
# 1902               False              False         False      False
# 1903                True              False         False      False
# 1904                True               True         False      False
#
#       pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 0             True           False        False            False
# 1            False           False        False            False
# 2            False           False        False             True
# 3             True           False        False            False
# 4            False           False        False            False
# ...            ...             ...          ...              ...
# 1900          True           False        False            False
# 1901         False           False        False            False
# 1902          True           False        False            False
# 1903         False            True        False            False
# 1904         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 0            False     False        True        False       False  False
# 1            False     False        True         True       False  False
# 2            False      True        True         True       False  False
# 3            False     False       False        False       False  False
# 4            False      True        True         True        True  False
# ...            ...       ...         ...          ...         ...    ...
# 1900         False      True        True         True        True   True
# 1901         False     False        True         True       False  False
# 1902         False     False       False         True       False  False
# 1903         False      True        True         True       False  False
# 1904         False      True        True         True        True  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 0               False             False           True           False
# 1               False             False           True           False
# 2               False              True           True            True
# 3               False             False          False           False
# 4               False              True           True           False
# ...               ...               ...            ...             ...
# 1900             True              True           True            True
# 1901            False             False           True            True
# 1902            False             False          False           False
# 1903            False             False           True            True
# 1904            False             False           True           False
#
# [1905 rows x 34 columns]

# %%
data >> select(columns_between( X.latitude , X.size_in_sqft , inclusive=False))
# Out:
#        latitude  longitude    price
# 0     25.000000  55.138932  2700000
# 1     25.106809  55.151201  2850000
# 2     25.063302  55.137728  1150000
# 3     25.227295  55.341761  2850000
# 4     25.114275  55.139764  1729200
# ...         ...        ...      ...
# 1900  25.176892  55.310712  1500000
# 1901  25.166145  55.276684  1230000
# 1902  25.206500  55.345056  2900000
# 1903  25.073858  55.229844   675000
# 1904  25.079130  55.154713   760887
#
# [1905 rows x 3 columns]

# %%
data >> select(columns_between( 2 , 5 , inclusive=True))
# Out:
#        latitude  longitude    price  size_in_sqft
# 0     25.000000  55.138932  2700000          1079
# 1     25.106809  55.151201  2850000          1582
# 2     25.063302  55.137728  1150000          1951
# 3     25.227295  55.341761  2850000          2020
# 4     25.114275  55.139764  1729200           507
# ...         ...        ...      ...           ...
# 1900  25.176892  55.310712  1500000          1087
# 1901  25.166145  55.276684  1230000           760
# 1902  25.206500  55.345056  2900000          1930
# 1903  25.073858  55.229844   675000           740
# 1904  25.079130  55.154713   760887           800
#
# [1905 rows x 4 columns]

# %%
( data >> select(columns_between( 2 , 5 , inclusive=False)) )
# Out:
#        latitude  longitude    price
# 0     25.000000  55.138932  2700000
# 1     25.106809  55.151201  2850000
# 2     25.063302  55.137728  1150000
# 3     25.227295  55.341761  2850000
# 4     25.114275  55.139764  1729200
# ...         ...        ...      ...
# 1900  25.176892  55.310712  1500000
# 1901  25.166145  55.276684  1230000
# 1902  25.206500  55.345056  2900000
# 1903  25.073858  55.229844   675000
# 1904  25.079130  55.154713   760887
#
# [1905 rows x 3 columns]

# %%
data >> select(columns_to(end_col=X.price , inclusive=True))
# Out:
#            id                       neighborhood   latitude  longitude  \
# 0     5528049                      Palm Jumeirah  25.000000  55.138932
# 1     6008529                      Palm Jumeirah  25.106809  55.151201
# 2     6034542               Jumeirah Lake Towers  25.063302  55.137728
# 3     6326063                    Culture Village  25.227295  55.341761
# 4     6356778                      Palm Jumeirah  25.114275  55.139764
# ...       ...                                ...        ...        ...
# 1900  7705450           Mohammed Bin Rashid City  25.176892  55.310712
# 1901  7706287           Mohammed Bin Rashid City  25.166145  55.276684
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  25.206500  55.345056
# 1903  7706591            Jumeirah Village Circle  25.073858  55.229844
# 1904  7706643               Jumeirah Lake Towers  25.079130  55.154713
#
#         price
# 0     2700000
# 1     2850000
# 2     1150000
# 3     2850000
# 4     1729200
# ...       ...
# 1900  1500000
# 1901  1230000
# 1902  2900000
# 1903   675000
# 1904   760887
#
# [1905 rows x 5 columns]

# %%
data >> select(columns_from(start_col=X.price))
# Out:
#         price  size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  \
# 0     2700000          1079         2502.32               1                2
# 1     2850000          1582         1801.52               2                2
# 2     1150000          1951          589.44               3                5
# 3     2850000          2020         1410.89               2                3
# 4     1729200           507         3410.65               0                1
# ...       ...           ...             ...             ...              ...
# 1900  1500000          1087         1379.94               2                2
# 1901  1230000           760         1618.42               1                2
# 1902  2900000          1930         1502.59               3                5
# 1903   675000           740          912.16               1                2
# 1904   760887           800          951.11               1                2
#
#      quality  maid_room  unfurnished  balcony  barbecue_area  \
# 0     Medium      False        False     True           True
# 1     Medium      False        False     True          False
# 2     Medium       True         True     True          False
# 3        Low      False         True     True          False
# 4     Medium      False        False    False          False
# ...      ...        ...          ...      ...            ...
# 1900   Ultra      False         True     True           True
# 1901  Medium      False        False     True          False
# 1902  Medium       True         True     True          False
# 1903  Medium      False         True     True          False
# 1904    High      False        False     True           True
#
#       built_in_wardrobes  central_ac  childrens_play_area  childrens_pool  \
# 0                  False        True                 True           False
# 1                   True        True                 True           False
# 2                   True       False                False           False
# 3                  False       False                False           False
# 4                   True        True                False           False
# ...                  ...         ...                  ...             ...
# 1900                True        True                 True            True
# 1901                True        True                 True           False
# 1902               False        True                 True           False
# 1903                True        True                 True           False
# 1904                True        True                 True            True
#
#       concierge  covered_parking  kitchen_appliances  lobby_in_building  \
# 0          True            False                True              False
# 1         False            False               False              False
# 2         False             True               False              False
# 3          True             True               False              False
# 4         False             True                True              False
# ...         ...              ...                 ...                ...
# 1900       True             True                True               True
# 1901       True            False                True              False
# 1902      False            False               False              False
# 1903      False             True                True              False
# 1904       True             True                True               True
#
#       maid_service  networked  pets_allowed  private_garden  private_gym  \
# 0            False      False          True           False        False
# 1            False      False         False           False        False
# 2            False      False         False           False        False
# 3            False      False          True           False        False
# 4            False       True         False           False        False
# ...            ...        ...           ...             ...          ...
# 1900          True       True          True           False        False
# 1901         False      False         False           False        False
# 1902         False      False          True           False        False
# 1903         False      False         False            True        False
# 1904         False      False         False           False        False
#
#       private_jacuzzi  private_pool  security  shared_gym  shared_pool  \
# 0               False         False     False        True        False
# 1               False         False     False        True         True
# 2                True         False      True        True         True
# 3               False         False     False       False        False
# 4               False         False      True        True         True
# ...               ...           ...       ...         ...          ...
# 1900            False         False      True        True         True
# 1901            False         False     False        True         True
# 1902            False         False     False       False         True
# 1903            False         False      True        True         True
# 1904            False         False      True        True         True
#
#       shared_spa  study  vastu_compliant  view_of_landmark  view_of_water  \
# 0          False  False            False             False           True
# 1          False  False            False             False           True
# 2          False  False            False              True           True
# 3          False  False            False             False          False
# 4           True  False            False              True           True
# ...          ...    ...              ...               ...            ...
# 1900        True   True             True              True           True
# 1901       False  False            False             False           True
# 1902       False  False            False             False          False
# 1903       False  False            False             False           True
# 1904        True  False            False             False           True
#
#       walk_in_closet
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
# ...              ...
# 1900            True
# 1901            True
# 1902           False
# 1903            True
# 1904           False
#
# [1905 rows x 34 columns]

# %% [markdown]
# We can also select rows of a data-set wit `row_slice`:

# %%
data >> row_slice([10,15])
# Out:
#          id    neighborhood   latitude  longitude    price  size_in_sqft  \
# 10  6473651  Downtown Dubai  25.198796  55.271342  3550000          1918
# 15  6526806   Palm Jumeirah  25.132021  55.151405  2349990          1109
#
#     price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 10         1850.89               3                4     Low      False
# 15         2119.02               1                1  Medium      False
#
#     unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# 10         True     True          False               False        True
# 15        False     True           True                True        True
#
#     childrens_play_area  childrens_pool  concierge  covered_parking  \
# 10                False           False      False            False
# 15                False           False       True            False
#
#     kitchen_appliances  lobby_in_building  maid_service  networked  \
# 10                True              False         False      False
# 15               False              False         False      False
#
#     pets_allowed  private_garden  private_gym  private_jacuzzi  private_pool  \
# 10         False           False        False            False         False
# 15         False           False        False            False         False
#
#     security  shared_gym  shared_pool  shared_spa  study  vastu_compliant  \
# 10     False       False         True       False  False            False
# 15     False        True         True       False  False            False
#
#     view_of_landmark  view_of_water  walk_in_closet
# 10             False           True           False
# 15             False           True           False

# %%
list(range(2,10)) # 2:9

data >> row_slice(list(range(2,10)))
# Out:
#         id          neighborhood   latitude  longitude    price  size_in_sqft  \
# 2  6034542  Jumeirah Lake Towers  25.063302  55.137728  1150000          1951
# 3  6326063       Culture Village  25.227295  55.341761  2850000          2020
# 4  6356778         Palm Jumeirah  25.114275  55.139764  1729200           507
# 5  6356784         Palm Jumeirah  25.114275  55.139764  3119900          1015
# 6  6356790         Palm Jumeirah  25.114275  55.139764  8503600          2062
# 7  6356797         Palm Jumeirah  25.114275  55.139764  3119900          1015
# 8  6376886         Palm Jumeirah  25.106668  55.149275  2100000          2186
# 9  6406935        Downtown Dubai  25.194935  55.282665  2690000          1521
#
#    price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  maid_room  \
# 2          589.44               3                5  Medium       True
# 3         1410.89               2                3     Low      False
# 4         3410.65               0                1  Medium      False
# 5         3073.79               1                2  Medium      False
# 6         4123.96               2                3    High       True
# 7         3073.79               1                2  Medium      False
# 8          960.66               3                3     Low      False
# 9         1768.57               2                3  Medium      False
#
#    unfurnished  balcony  barbecue_area  built_in_wardrobes  central_ac  \
# 2         True     True          False                True       False
# 3         True     True          False               False       False
# 4        False    False          False                True        True
# 5        False    False          False                True        True
# 6        False    False          False                True        True
# 7        False    False          False                True        True
# 8        False    False          False               False       False
# 9        False     True          False                True        True
#
#    childrens_play_area  childrens_pool  concierge  covered_parking  \
# 2                False           False      False             True
# 3                False           False       True             True
# 4                False           False      False             True
# 5                False           False      False             True
# 6                False           False      False             True
# 7                False           False      False             True
# 8                False           False      False            False
# 9                False           False      False             True
#
#    kitchen_appliances  lobby_in_building  maid_service  networked  \
# 2               False              False         False      False
# 3               False              False         False      False
# 4                True              False         False       True
# 5                True              False         False       True
# 6                True              False         False       True
# 7                True              False         False       True
# 8               False              False         False      False
# 9                True              False         False      False
#
#    pets_allowed  private_garden  private_gym  private_jacuzzi  private_pool  \
# 2         False           False        False             True         False
# 3          True           False        False            False         False
# 4         False           False        False            False         False
# 5         False           False        False            False         False
# 6         False           False        False            False         False
# 7         False           False        False            False         False
# 8         False           False        False            False         False
# 9         False           False        False            False         False
#
#    security  shared_gym  shared_pool  shared_spa  study  vastu_compliant  \
# 2      True        True         True       False  False            False
# 3     False       False        False       False  False            False
# 4      True        True         True        True  False            False
# 5      True        True         True        True  False            False
# 6      True        True         True        True  False            False
# 7      True        True         True        True  False            False
# 8     False       False        False       False  False            False
# 9     False        True         True       False  False            False
#
#    view_of_landmark  view_of_water  walk_in_closet
# 2              True           True            True
# 3             False          False           False
# 4              True           True           False
# 5              True           True           False
# 6              True           True            True
# 7              True           True           False
# 8             False          False           False
# 9             False           True           False

# %% [markdown]
# We can use `row_slice` as column_slice using de transpose data-set :

# %%
(data.T >> row_slice( [2,3,5,7]) ).T 
# select the columns 3,4,6,8 of the data-frame

# data-frame.T is the way in Pandas to transpose a data-frame
# Out:
#        latitude  longitude size_in_sqft no_of_bedrooms
# 0          25.0  55.138932         1079              1
# 1     25.106809  55.151201         1582              2
# 2     25.063302  55.137728         1951              3
# 3     25.227295  55.341761         2020              2
# 4     25.114275  55.139764          507              0
# ...         ...        ...          ...            ...
# 1900  25.176892  55.310712         1087              2
# 1901  25.166145  55.276684          760              1
# 1902    25.2065  55.345056         1930              3
# 1903  25.073858  55.229844          740              1
# 1904   25.07913  55.154713          800              1
#
# [1905 rows x 4 columns]

# %% [markdown]
# ## Sampling <a class="anchor" id="3"></a>

# %% [markdown]
# We can extraxt a sample of the rows of a data-set as follows:

# %%
data >> sample(frac=0.15, replace=False)
# Out:
#            id             neighborhood   latitude  longitude    price  \
# 1816  7698708  Jumeirah Village Circle  25.066475  55.214533   365000
# 1139  7651845  Jumeirah Village Circle  25.053111  55.206630   280000
# 961   7632829           Downtown Dubai  25.191404  55.273896   999999
# 1484  7673726             Dubai Marina  25.086376  55.147360  1550000
# 1607  7684402            Palm Jumeirah  25.112237  55.138630  2300943
# ...       ...                      ...        ...        ...      ...
# 1454  7671819             Dubai Marina  25.071718  55.135145   720000
# 949   7631138           Downtown Dubai  25.201842  55.280473  1390000
# 1039  7642767            Palm Jumeirah  25.126233  55.154510  5045846
# 515   7575254           Downtown Dubai  25.196398  55.271002  1025000
# 1727  7693164               Motor City  25.044699  55.246543   600000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 1816           419          871.12               0                1  Medium
# 1139           387          723.51               0                1     Low
# 961            838         1193.32               1                1  Medium
# 1484           860         1802.33               1                2     Low
# 1607          1095         2101.32               2                3  Medium
# ...            ...             ...             ...              ...     ...
# 1454           941          765.14               1                2  Medium
# 949           1162         1196.21               2                3  Medium
# 1039          1740         2899.91               2                2  Medium
# 515            740         1385.14               1                2  Medium
# 1727          1044          574.71               1                2  Medium
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 1816      False        False     True          False                True
# 1139      False         True     True          False                True
# 961       False         True     True          False                True
# 1484      False        False    False          False               False
# 1607      False         True     True          False                True
# ...         ...          ...      ...            ...                 ...
# 1454      False         True     True          False                True
# 949       False         True     True          False                True
# 1039      False        False     True          False                True
# 515       False         True     True          False                True
# 1727      False         True     True          False                True
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 1816        True                 True           False      False
# 1139       False                 True           False      False
# 961         True                False           False       True
# 1484       False                False           False      False
# 1607        True                False           False      False
# ...          ...                  ...             ...        ...
# 1454       False                 True           False      False
# 949         True                 True            True      False
# 1039        True                False           False      False
# 515         True                False           False      False
# 1727        True                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 1816             True                True              False          True
# 1139             True               False              False         False
# 961              True                True              False         False
# 1484            False               False              False         False
# 1607             True               False              False         False
# ...               ...                 ...                ...           ...
# 1454             True               False              False         False
# 949             False               False               True         False
# 1039            False                True              False         False
# 515              True                True              False         False
# 1727             True               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 1816      False          True           False        False            False
# 1139      False          True           False        False            False
# 961       False          True           False        False            False
# 1484      False         False           False        False            False
# 1607      False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1454      False         False           False        False            False
# 949       False         False           False        False            False
# 1039      False         False           False        False            False
# 515       False          True           False        False            False
# 1727      False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 1816         False      True        True         True       False  False
# 1139         False     False       False        False       False  False
# 961          False     False        True         True       False  False
# 1484         False     False       False        False       False  False
# 1607         False     False        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1454          True     False        True         True       False  False
# 949          False      True        True         True       False  False
# 1039         False      True        True         True       False  False
# 515          False     False        True         True       False  False
# 1727         False     False        True         True       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 1816            False              True          False           False
# 1139            False             False          False           False
# 961             False             False          False           False
# 1484            False             False          False           False
# 1607            False             False           True           False
# ...               ...               ...            ...             ...
# 1454            False             False           True           False
# 949             False              True          False           False
# 1039            False             False           True           False
# 515             False             False           True           False
# 1727            False             False          False           False
#
# [286 rows x 38 columns]

# %%
data >> sample(n=15, replace=False)
# Out:
#            id              neighborhood   latitude  longitude    price  \
# 236   7453919                Motor City  25.046706  55.246714   629000
# 1054  7644074  Jumeirah Beach Residence  25.073590  55.126352  1980000
# 711   7602634             Dubai Harbour  25.099380  55.141275  4222888
# 1137  7651633                    Meydan  25.172418  55.306951   525000
# 1519  7677927                      DIFC  25.207533  55.277978  2100000
# 1276  7661690              Dubai Marina  25.074307  55.132694  1300000
# 459   7554665            Downtown Dubai  25.196593  55.269631  1275000
# 1671  7688380            Downtown Dubai  25.197520  55.270168  1100000
# 1167  7652627   Jumeirah Village Circle  25.050227  55.213350   440500
# 681   7599900                  Jumeirah  25.240419  55.252770  1700000
# 1075  7645950                 The Views  25.093596  55.166634  1500000
# 1117  7650786   Jumeirah Village Circle  25.046296  55.200783   439205
# 707   7602004   Jumeirah Village Circle  25.051528  55.212972  1131000
# 1006  7638368   Jumeirah Village Circle  25.046296  55.200697   443000
# 674   7599517                    Mirdif  25.227337  55.441623  1688000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 236           1051          598.48               1                1     Low
# 1054           705         2808.51               1                2  Medium
# 711           1968         2145.78               3                4     Low
# 1137           330         1590.91               0                1  Medium
# 1519          1836         1143.79               2                2  Medium
# 1276          1076         1208.18               1                2  Medium
# 459           1282          994.54               2                3  Medium
# 1671           744         1478.49               1                2     Low
# 1167           520          847.12               0                1   Ultra
# 681           1200         1416.67               2                3     Low
# 1075          2528          593.35               3                3  Medium
# 1117           401         1095.27               0                1  Medium
# 707           1558          725.93               2                3   Ultra
# 1006           423         1047.28               0                1     Low
# 674           1581         1067.68               3                4  Medium
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 236       False         True     True          False               False
# 1054      False         True    False          False                True
# 711       False         True     True          False                True
# 1137      False         True     True          False                True
# 1519      False         True     True          False                True
# 1276      False         True     True           True                True
# 459       False         True     True          False                True
# 1671      False        False     True          False                True
# 1167      False        False     True           True                True
# 681       False         True    False          False                True
# 1075      False         True     True           True                True
# 1117      False         True     True          False               False
# 707        True         True     True           True                True
# 1006      False         True    False          False               False
# 674        True         True     True          False                True
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 236         True                False           False      False
# 1054        True                False           False      False
# 711        False                False           False       True
# 1137        True                 True           False      False
# 1519        True                False           False      False
# 1276        True                 True           False       True
# 459         True                False           False      False
# 1671       False                False           False      False
# 1167        True                 True            True       True
# 681         True                False           False      False
# 1075        True                 True           False      False
# 1117        True                False           False       True
# 707         True                 True            True       True
# 1006       False                False           False      False
# 674         True                 True           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 236             False               False              False         False
# 1054             True               False              False         False
# 711             False               False              False         False
# 1137            False               False              False         False
# 1519             True                True              False         False
# 1276            False                True              False         False
# 459              True                True              False         False
# 1671             True               False              False         False
# 1167             True                True               True          True
# 681             False               False              False         False
# 1075            False                True              False         False
# 1117             True               False               True         False
# 707              True                True               True          True
# 1006            False               False              False         False
# 674              True               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 236       False         False           False        False            False
# 1054      False         False           False        False            False
# 711       False         False           False        False            False
# 1137      False         False           False        False            False
# 1519      False          True           False        False            False
# 1276      False         False           False        False            False
# 459       False         False           False        False            False
# 1671      False         False           False        False            False
# 1167       True          True           False        False            False
# 681       False         False           False        False            False
# 1075      False          True           False        False            False
# 1117      False         False           False        False            False
# 707        True         False           False        False            False
# 1006      False         False           False        False            False
# 674       False          True           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 236          False     False       False         True       False  False
# 1054         False      True        True         True       False  False
# 711          False     False       False        False       False  False
# 1137         False      True        True         True       False  False
# 1519         False     False        True         True       False  False
# 1276         False     False        True         True       False  False
# 459          False      True        True         True       False  False
# 1671         False     False        True        False       False  False
# 1167         False      True        True         True        True   True
# 681          False     False        True         True       False  False
# 1075         False     False        True         True       False  False
# 1117         False      True        True         True       False  False
# 707          False      True        True         True        True   True
# 1006         False      True        True         True       False  False
# 674          False      True        True         True       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 236             False             False          False           False
# 1054            False             False           True           False
# 711             False              True           True           False
# 1137            False             False          False           False
# 1519            False             False           True           False
# 1276            False             False           True           False
# 459             False             False           True           False
# 1671            False             False          False           False
# 1167             True              True           True            True
# 681             False              True          False           False
# 1075            False             False          False           False
# 1117            False              True           True            True
# 707              True              True           True            True
# 1006            False             False          False           False
# 674             False              True          False           False

# %% [markdown]
# ## Filtering <a class="anchor" id="4"></a>

# %% [markdown]
# We can obtain the rows with different values for one variable (column) as follows:

# %%
data >> distinct(X.price)
# Out:
#            id          neighborhood   latitude  longitude     price  \
# 0     5528049         Palm Jumeirah  25.000000  55.138932   2700000
# 1     6008529         Palm Jumeirah  25.106809  55.151201   2850000
# 2     6034542  Jumeirah Lake Towers  25.063302  55.137728   1150000
# 4     6356778         Palm Jumeirah  25.114275  55.139764   1729200
# 5     6356784         Palm Jumeirah  25.114275  55.139764   3119900
# ...       ...                   ...        ...        ...       ...
# 1885  7703691         Palm Jumeirah  25.103972  55.149621  31440000
# 1886  7703701         Dubai Harbour  25.099380  55.141275   4856888
# 1894  7704943        Downtown Dubai  25.191107  55.269910    980888
# 1896  7705124        Downtown Dubai  25.196489  55.272126  18040888
# 1904  7706643  Jumeirah Lake Towers  25.079130  55.154713    760887
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 0             1079         2502.32               1                2  Medium
# 1             1582         1801.52               2                2  Medium
# 2             1951          589.44               3                5  Medium
# 4              507         3410.65               0                1  Medium
# 5             1015         3073.79               1                2  Medium
# ...            ...             ...             ...              ...     ...
# 1885          6542         4805.87               4                6    High
# 1886          2088         2326.10               3                3  Medium
# 1894          1088          901.55               1                1  Medium
# 1896          5253         3434.40               4                4  Medium
# 1904           800          951.11               1                2    High
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 0         False        False     True           True               False
# 1         False        False     True          False                True
# 2          True         True     True          False                True
# 4         False        False    False          False                True
# 5         False        False    False          False                True
# ...         ...          ...      ...            ...                 ...
# 1885       True        False     True          False               False
# 1886       True         True     True          False               False
# 1894      False         True     True          False               False
# 1896       True         True     True          False                True
# 1904      False        False     True           True                True
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 0           True                 True           False       True
# 1           True                 True           False      False
# 2          False                False           False      False
# 4           True                False           False      False
# 5           True                False           False      False
# ...          ...                  ...             ...        ...
# 1885        True                False           False       True
# 1886        True                False           False      False
# 1894        True                False           False       True
# 1896        True                 True           False      False
# 1904        True                 True            True       True
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 0               False                True              False         False
# 1               False               False              False         False
# 2                True               False              False         False
# 4                True                True              False         False
# 5                True                True              False         False
# ...               ...                 ...                ...           ...
# 1885             True                True              False          True
# 1886             True               False              False         False
# 1894             True                True              False         False
# 1896            False               False              False         False
# 1904             True                True               True         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 0         False          True           False        False            False
# 1         False         False           False        False            False
# 2         False         False           False        False             True
# 4          True         False           False        False            False
# 5          True         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1885      False          True           False        False             True
# 1886      False          True           False        False            False
# 1894      False         False           False        False            False
# 1896      False         False           False        False            False
# 1904      False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 0            False     False        True        False       False  False
# 1            False     False        True         True       False  False
# 2            False      True        True         True       False  False
# 4            False      True        True         True        True  False
# 5            False      True        True         True        True  False
# ...            ...       ...         ...          ...         ...    ...
# 1885          True      True        True         True        True  False
# 1886          True      True        True         True        True  False
# 1894         False     False        True         True       False  False
# 1896         False     False        True         True       False   True
# 1904         False      True        True         True        True  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 0               False             False           True           False
# 1               False             False           True           False
# 2               False              True           True            True
# 4               False              True           True           False
# 5               False              True           True           False
# ...               ...               ...            ...             ...
# 1885            False              True           True            True
# 1886            False             False           True           False
# 1894            False             False          False            True
# 1896            False             False          False           False
# 1904            False             False           True           False
#
# [821 rows x 38 columns]

# %% [markdown]
# We would get the same if we would use `drop_duplicate`, that is a function of `Pandas`

# %%
data.drop_duplicates('price')
# Out:
#            id          neighborhood   latitude  longitude     price  \
# 0     5528049         Palm Jumeirah  25.000000  55.138932   2700000
# 1     6008529         Palm Jumeirah  25.106809  55.151201   2850000
# 2     6034542  Jumeirah Lake Towers  25.063302  55.137728   1150000
# 4     6356778         Palm Jumeirah  25.114275  55.139764   1729200
# 5     6356784         Palm Jumeirah  25.114275  55.139764   3119900
# ...       ...                   ...        ...        ...       ...
# 1885  7703691         Palm Jumeirah  25.103972  55.149621  31440000
# 1886  7703701         Dubai Harbour  25.099380  55.141275   4856888
# 1894  7704943        Downtown Dubai  25.191107  55.269910    980888
# 1896  7705124        Downtown Dubai  25.196489  55.272126  18040888
# 1904  7706643  Jumeirah Lake Towers  25.079130  55.154713    760887
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 0             1079         2502.32               1                2  Medium
# 1             1582         1801.52               2                2  Medium
# 2             1951          589.44               3                5  Medium
# 4              507         3410.65               0                1  Medium
# 5             1015         3073.79               1                2  Medium
# ...            ...             ...             ...              ...     ...
# 1885          6542         4805.87               4                6    High
# 1886          2088         2326.10               3                3  Medium
# 1894          1088          901.55               1                1  Medium
# 1896          5253         3434.40               4                4  Medium
# 1904           800          951.11               1                2    High
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 0         False        False     True           True               False
# 1         False        False     True          False                True
# 2          True         True     True          False                True
# 4         False        False    False          False                True
# 5         False        False    False          False                True
# ...         ...          ...      ...            ...                 ...
# 1885       True        False     True          False               False
# 1886       True         True     True          False               False
# 1894      False         True     True          False               False
# 1896       True         True     True          False                True
# 1904      False        False     True           True                True
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 0           True                 True           False       True
# 1           True                 True           False      False
# 2          False                False           False      False
# 4           True                False           False      False
# 5           True                False           False      False
# ...          ...                  ...             ...        ...
# 1885        True                False           False       True
# 1886        True                False           False      False
# 1894        True                False           False       True
# 1896        True                 True           False      False
# 1904        True                 True            True       True
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 0               False                True              False         False
# 1               False               False              False         False
# 2                True               False              False         False
# 4                True                True              False         False
# 5                True                True              False         False
# ...               ...                 ...                ...           ...
# 1885             True                True              False          True
# 1886             True               False              False         False
# 1894             True                True              False         False
# 1896            False               False              False         False
# 1904             True                True               True         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 0         False          True           False        False            False
# 1         False         False           False        False            False
# 2         False         False           False        False             True
# 4          True         False           False        False            False
# 5          True         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1885      False          True           False        False             True
# 1886      False          True           False        False            False
# 1894      False         False           False        False            False
# 1896      False         False           False        False            False
# 1904      False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 0            False     False        True        False       False  False
# 1            False     False        True         True       False  False
# 2            False      True        True         True       False  False
# 4            False      True        True         True        True  False
# 5            False      True        True         True        True  False
# ...            ...       ...         ...          ...         ...    ...
# 1885          True      True        True         True        True  False
# 1886          True      True        True         True        True  False
# 1894         False     False        True         True       False  False
# 1896         False     False        True         True       False   True
# 1904         False      True        True         True        True  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 0               False             False           True           False
# 1               False             False           True           False
# 2               False              True           True            True
# 4               False              True           True           False
# 5               False              True           True           False
# ...               ...               ...            ...             ...
# 1885            False              True           True            True
# 1886            False             False           True           False
# 1894            False             False          False            True
# 1896            False             False          False           False
# 1904            False             False           True           False
#
# [821 rows x 38 columns]

# %% [markdown]
# We can filter rows (observations) using conditions on the variables (columns) as folllow:

# %%
data >> filter_by(X.quality == 'Low' , X.price > 500000 )
# Out:
#            id              neighborhood   latitude  longitude    price  \
# 3     6326063           Culture Village  25.227295  55.341761  2850000
# 8     6376886             Palm Jumeirah  25.106668  55.149275  2100000
# 10    6473651            Downtown Dubai  25.198796  55.271342  3550000
# 11    6493425              Dubai Marina  25.075017  55.137997  2094999
# 12    6493433              Dubai Marina  25.075017  55.137997  1049999
# ...       ...                       ...        ...        ...      ...
# 1884  7703575  Jumeirah Beach Residence  25.072569  55.126527  3300000
# 1887  7703806                 City Walk  25.208262  55.262829  1396000
# 1889  7703914             Palm Jumeirah  25.106668  55.149275  1400000
# 1891  7704040           Culture Village  25.226946  55.343628  7000000
# 1895  7705052              Dubai Marina  25.081243  55.145120  1350000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 3             2020         1410.89               2                3     Low
# 8             2186          960.66               3                3     Low
# 10            1918         1850.89               3                4     Low
# 11            1058         1980.15               2                3     Low
# 12             609         1724.14               1                2     Low
# ...            ...             ...             ...              ...     ...
# 1884          1180         2796.61               2                3     Low
# 1887          1672          834.93               1                2     Low
# 1889          1173         1193.52               1                1     Low
# 1891          4068         1720.75               4                6     Low
# 1895          1578          855.51               2                4     Low
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 3         False         True     True          False               False
# 8         False        False    False          False               False
# 10        False         True     True          False               False
# 11        False         True     True          False                True
# 12        False         True    False          False                True
# ...         ...          ...      ...            ...                 ...
# 1884      False         True    False          False                True
# 1887      False        False    False          False               False
# 1889      False        False    False          False               False
# 1891      False        False    False          False               False
# 1895      False        False    False          False               False
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 3          False                False           False       True
# 8          False                False           False      False
# 10          True                False           False      False
# 11          True                False           False      False
# 12          True                False           False      False
# ...          ...                  ...             ...        ...
# 1884       False                False           False       True
# 1887       False                False           False      False
# 1889       False                False           False      False
# 1891       False                False           False      False
# 1895       False                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 3                True               False              False         False
# 8               False               False              False         False
# 10              False                True              False         False
# 11              False               False              False         False
# 12              False                True              False         False
# ...               ...                 ...                ...           ...
# 1884             True               False              False         False
# 1887            False               False              False         False
# 1889            False               False              False         False
# 1891            False               False              False         False
# 1895            False               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 3         False          True           False        False            False
# 8         False         False           False        False            False
# 10        False         False           False        False            False
# 11        False         False           False        False            False
# 12        False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1884      False         False           False        False            False
# 1887      False         False           False        False            False
# 1889      False         False           False        False            False
# 1891      False         False           False        False            False
# 1895      False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 3            False     False       False        False       False  False
# 8            False     False       False        False       False  False
# 10           False     False       False         True       False  False
# 11           False     False        True         True       False  False
# 12           False     False        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1884         False     False       False         True       False  False
# 1887         False     False       False        False       False  False
# 1889         False     False       False        False       False  False
# 1891         False     False       False        False       False  False
# 1895         False     False       False        False       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 3               False             False          False           False
# 8               False             False          False           False
# 10              False             False           True           False
# 11              False             False          False           False
# 12              False             False          False           False
# ...               ...               ...            ...             ...
# 1884            False             False          False           False
# 1887            False             False          False           False
# 1889            False             False          False           False
# 1891            False             False          False           False
# 1895            False             False          False           False
#
# [511 rows x 38 columns]

# %%
data >> filter_by( (X.quality == 'Low') &  (X.price > 500000) )
# Out:
#            id              neighborhood   latitude  longitude    price  \
# 3     6326063           Culture Village  25.227295  55.341761  2850000
# 8     6376886             Palm Jumeirah  25.106668  55.149275  2100000
# 10    6473651            Downtown Dubai  25.198796  55.271342  3550000
# 11    6493425              Dubai Marina  25.075017  55.137997  2094999
# 12    6493433              Dubai Marina  25.075017  55.137997  1049999
# ...       ...                       ...        ...        ...      ...
# 1884  7703575  Jumeirah Beach Residence  25.072569  55.126527  3300000
# 1887  7703806                 City Walk  25.208262  55.262829  1396000
# 1889  7703914             Palm Jumeirah  25.106668  55.149275  1400000
# 1891  7704040           Culture Village  25.226946  55.343628  7000000
# 1895  7705052              Dubai Marina  25.081243  55.145120  1350000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 3             2020         1410.89               2                3     Low
# 8             2186          960.66               3                3     Low
# 10            1918         1850.89               3                4     Low
# 11            1058         1980.15               2                3     Low
# 12             609         1724.14               1                2     Low
# ...            ...             ...             ...              ...     ...
# 1884          1180         2796.61               2                3     Low
# 1887          1672          834.93               1                2     Low
# 1889          1173         1193.52               1                1     Low
# 1891          4068         1720.75               4                6     Low
# 1895          1578          855.51               2                4     Low
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 3         False         True     True          False               False
# 8         False        False    False          False               False
# 10        False         True     True          False               False
# 11        False         True     True          False                True
# 12        False         True    False          False                True
# ...         ...          ...      ...            ...                 ...
# 1884      False         True    False          False                True
# 1887      False        False    False          False               False
# 1889      False        False    False          False               False
# 1891      False        False    False          False               False
# 1895      False        False    False          False               False
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 3          False                False           False       True
# 8          False                False           False      False
# 10          True                False           False      False
# 11          True                False           False      False
# 12          True                False           False      False
# ...          ...                  ...             ...        ...
# 1884       False                False           False       True
# 1887       False                False           False      False
# 1889       False                False           False      False
# 1891       False                False           False      False
# 1895       False                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 3                True               False              False         False
# 8               False               False              False         False
# 10              False                True              False         False
# 11              False               False              False         False
# 12              False                True              False         False
# ...               ...                 ...                ...           ...
# 1884             True               False              False         False
# 1887            False               False              False         False
# 1889            False               False              False         False
# 1891            False               False              False         False
# 1895            False               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 3         False          True           False        False            False
# 8         False         False           False        False            False
# 10        False         False           False        False            False
# 11        False         False           False        False            False
# 12        False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1884      False         False           False        False            False
# 1887      False         False           False        False            False
# 1889      False         False           False        False            False
# 1891      False         False           False        False            False
# 1895      False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 3            False     False       False        False       False  False
# 8            False     False       False        False       False  False
# 10           False     False       False         True       False  False
# 11           False     False        True         True       False  False
# 12           False     False        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1884         False     False       False         True       False  False
# 1887         False     False       False        False       False  False
# 1889         False     False       False        False       False  False
# 1891         False     False       False        False       False  False
# 1895         False     False       False        False       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 3               False             False          False           False
# 8               False             False          False           False
# 10              False             False           True           False
# 11              False             False          False           False
# 12              False             False          False           False
# ...               ...               ...            ...             ...
# 1884            False             False          False           False
# 1887            False             False          False           False
# 1889            False             False          False           False
# 1891            False             False          False           False
# 1895            False             False          False           False
#
# [511 rows x 38 columns]

# %% [markdown]
# Another available syntax with which we can do the previous operation:

# %%
data >> filter_by( (X['quality'] == 'Low') &  (X['price'] > 500000) )
# Out:
#            id              neighborhood   latitude  longitude    price  \
# 3     6326063           Culture Village  25.227295  55.341761  2850000
# 8     6376886             Palm Jumeirah  25.106668  55.149275  2100000
# 10    6473651            Downtown Dubai  25.198796  55.271342  3550000
# 11    6493425              Dubai Marina  25.075017  55.137997  2094999
# 12    6493433              Dubai Marina  25.075017  55.137997  1049999
# ...       ...                       ...        ...        ...      ...
# 1884  7703575  Jumeirah Beach Residence  25.072569  55.126527  3300000
# 1887  7703806                 City Walk  25.208262  55.262829  1396000
# 1889  7703914             Palm Jumeirah  25.106668  55.149275  1400000
# 1891  7704040           Culture Village  25.226946  55.343628  7000000
# 1895  7705052              Dubai Marina  25.081243  55.145120  1350000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 3             2020         1410.89               2                3     Low
# 8             2186          960.66               3                3     Low
# 10            1918         1850.89               3                4     Low
# 11            1058         1980.15               2                3     Low
# 12             609         1724.14               1                2     Low
# ...            ...             ...             ...              ...     ...
# 1884          1180         2796.61               2                3     Low
# 1887          1672          834.93               1                2     Low
# 1889          1173         1193.52               1                1     Low
# 1891          4068         1720.75               4                6     Low
# 1895          1578          855.51               2                4     Low
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 3         False         True     True          False               False
# 8         False        False    False          False               False
# 10        False         True     True          False               False
# 11        False         True     True          False                True
# 12        False         True    False          False                True
# ...         ...          ...      ...            ...                 ...
# 1884      False         True    False          False                True
# 1887      False        False    False          False               False
# 1889      False        False    False          False               False
# 1891      False        False    False          False               False
# 1895      False        False    False          False               False
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 3          False                False           False       True
# 8          False                False           False      False
# 10          True                False           False      False
# 11          True                False           False      False
# 12          True                False           False      False
# ...          ...                  ...             ...        ...
# 1884       False                False           False       True
# 1887       False                False           False      False
# 1889       False                False           False      False
# 1891       False                False           False      False
# 1895       False                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 3                True               False              False         False
# 8               False               False              False         False
# 10              False                True              False         False
# 11              False               False              False         False
# 12              False                True              False         False
# ...               ...                 ...                ...           ...
# 1884             True               False              False         False
# 1887            False               False              False         False
# 1889            False               False              False         False
# 1891            False               False              False         False
# 1895            False               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 3         False          True           False        False            False
# 8         False         False           False        False            False
# 10        False         False           False        False            False
# 11        False         False           False        False            False
# 12        False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1884      False         False           False        False            False
# 1887      False         False           False        False            False
# 1889      False         False           False        False            False
# 1891      False         False           False        False            False
# 1895      False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 3            False     False       False        False       False  False
# 8            False     False       False        False       False  False
# 10           False     False       False         True       False  False
# 11           False     False        True         True       False  False
# 12           False     False        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1884         False     False       False         True       False  False
# 1887         False     False       False        False       False  False
# 1889         False     False       False        False       False  False
# 1891         False     False       False        False       False  False
# 1895         False     False       False        False       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 3               False             False          False           False
# 8               False             False          False           False
# 10              False             False           True           False
# 11              False             False          False           False
# 12              False             False          False           False
# ...               ...               ...            ...             ...
# 1884            False             False          False           False
# 1887            False             False          False           False
# 1889            False             False          False           False
# 1891            False             False          False           False
# 1895            False             False          False           False
#
# [511 rows x 38 columns]

# %% [markdown]
# More examples of filter conditions:

# %%
data >> filter_by( (X.quality == 'Low') | (X.price > 500000) )
# Out:
#            id                       neighborhood   latitude  longitude  \
# 0     5528049                      Palm Jumeirah  25.000000  55.138932
# 1     6008529                      Palm Jumeirah  25.106809  55.151201
# 2     6034542               Jumeirah Lake Towers  25.063302  55.137728
# 3     6326063                    Culture Village  25.227295  55.341761
# 4     6356778                      Palm Jumeirah  25.114275  55.139764
# ...       ...                                ...        ...        ...
# 1900  7705450           Mohammed Bin Rashid City  25.176892  55.310712
# 1901  7706287           Mohammed Bin Rashid City  25.166145  55.276684
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  25.206500  55.345056
# 1903  7706591            Jumeirah Village Circle  25.073858  55.229844
# 1904  7706643               Jumeirah Lake Towers  25.079130  55.154713
#
#         price  size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  \
# 0     2700000          1079         2502.32               1                2
# 1     2850000          1582         1801.52               2                2
# 2     1150000          1951          589.44               3                5
# 3     2850000          2020         1410.89               2                3
# 4     1729200           507         3410.65               0                1
# ...       ...           ...             ...             ...              ...
# 1900  1500000          1087         1379.94               2                2
# 1901  1230000           760         1618.42               1                2
# 1902  2900000          1930         1502.59               3                5
# 1903   675000           740          912.16               1                2
# 1904   760887           800          951.11               1                2
#
#      quality  maid_room  unfurnished  balcony  barbecue_area  \
# 0     Medium      False        False     True           True
# 1     Medium      False        False     True          False
# 2     Medium       True         True     True          False
# 3        Low      False         True     True          False
# 4     Medium      False        False    False          False
# ...      ...        ...          ...      ...            ...
# 1900   Ultra      False         True     True           True
# 1901  Medium      False        False     True          False
# 1902  Medium       True         True     True          False
# 1903  Medium      False         True     True          False
# 1904    High      False        False     True           True
#
#       built_in_wardrobes  central_ac  childrens_play_area  childrens_pool  \
# 0                  False        True                 True           False
# 1                   True        True                 True           False
# 2                   True       False                False           False
# 3                  False       False                False           False
# 4                   True        True                False           False
# ...                  ...         ...                  ...             ...
# 1900                True        True                 True            True
# 1901                True        True                 True           False
# 1902               False        True                 True           False
# 1903                True        True                 True           False
# 1904                True        True                 True            True
#
#       concierge  covered_parking  kitchen_appliances  lobby_in_building  \
# 0          True            False                True              False
# 1         False            False               False              False
# 2         False             True               False              False
# 3          True             True               False              False
# 4         False             True                True              False
# ...         ...              ...                 ...                ...
# 1900       True             True                True               True
# 1901       True            False                True              False
# 1902      False            False               False              False
# 1903      False             True                True              False
# 1904       True             True                True               True
#
#       maid_service  networked  pets_allowed  private_garden  private_gym  \
# 0            False      False          True           False        False
# 1            False      False         False           False        False
# 2            False      False         False           False        False
# 3            False      False          True           False        False
# 4            False       True         False           False        False
# ...            ...        ...           ...             ...          ...
# 1900          True       True          True           False        False
# 1901         False      False         False           False        False
# 1902         False      False          True           False        False
# 1903         False      False         False            True        False
# 1904         False      False         False           False        False
#
#       private_jacuzzi  private_pool  security  shared_gym  shared_pool  \
# 0               False         False     False        True        False
# 1               False         False     False        True         True
# 2                True         False      True        True         True
# 3               False         False     False       False        False
# 4               False         False      True        True         True
# ...               ...           ...       ...         ...          ...
# 1900            False         False      True        True         True
# 1901            False         False     False        True         True
# 1902            False         False     False       False         True
# 1903            False         False      True        True         True
# 1904            False         False      True        True         True
#
#       shared_spa  study  vastu_compliant  view_of_landmark  view_of_water  \
# 0          False  False            False             False           True
# 1          False  False            False             False           True
# 2          False  False            False              True           True
# 3          False  False            False             False          False
# 4           True  False            False              True           True
# ...          ...    ...              ...               ...            ...
# 1900        True   True             True              True           True
# 1901       False  False            False             False           True
# 1902       False  False            False             False          False
# 1903       False  False            False             False           True
# 1904        True  False            False             False           True
#
#       walk_in_closet
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
# ...              ...
# 1900            True
# 1901            True
# 1902           False
# 1903            True
# 1904           False
#
# [1815 rows x 38 columns]

# %%
data >> filter_by( ~ ( (X.quality == 'Low') | (X.price > 500000) ) )
# Out:
#            id             neighborhood   latitude  longitude   price  \
# 49    7033393              DAMAC Hills  25.016736  55.251010  365000
# 55    7075159     Jumeirah Lake Towers  25.065736  55.137452  375000
# 146   7346962        Dubai Sports City  25.044572  55.218948  390000
# 160   7376067        Dubai Sports City  25.042264  55.217360  410000
# 197   7419623  Jumeirah Village Circle  25.063265  55.215131  410000
# ...       ...                      ...        ...        ...     ...
# 1845  7700464  Jumeirah Village Circle  25.046296  55.200783  443850
# 1849  7700952     Jumeirah Lake Towers  25.071246  55.140806  499000
# 1857  7701727     Jumeirah Lake Towers  25.078148  55.148277  400888
# 1874  7702410              Town Square  25.003730  55.297034  488888
# 1897  7705293                  Al Quoz  25.153080  55.254242  360000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 49             451          809.31               0                1  Medium
# 55             450          833.33               0                1  Medium
# 146            849          459.36               1                2  Medium
# 160            969          423.12               1                2  Medium
# 197            738          555.56               1                1  Medium
# ...            ...             ...             ...              ...     ...
# 1845           422         1051.78               0                1  Medium
# 1849           672          742.56               1                1  Medium
# 1857           403          994.76               0                1  Medium
# 1874           698          700.41               1                2  Medium
# 1897           600          600.00               0                1  Medium
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 49        False         True     True          False                True
# 55        False         True     True          False                True
# 146       False        False     True          False                True
# 160       False         True     True          False                True
# 197       False         True     True           True                True
# ...         ...          ...      ...            ...                 ...
# 1845      False         True    False          False                True
# 1849      False         True     True          False                True
# 1857      False        False     True           True                True
# 1874      False         True     True          False                True
# 1897      False        False     True          False               False
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 49          True                False           False      False
# 55          True                False           False      False
# 146         True                False           False      False
# 160         True                False           False       True
# 197         True                False           False      False
# ...          ...                  ...             ...        ...
# 1845        True                 True           False      False
# 1849        True                False           False      False
# 1857        True                 True           False       True
# 1874        True                 True           False      False
# 1897        True                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 49               True               False              False         False
# 55               True               False              False         False
# 146              True                True              False         False
# 160             False                True              False         False
# 197              True               False              False         False
# ...               ...                 ...                ...           ...
# 1845             True               False              False         False
# 1849             True               False              False         False
# 1857             True                True              False         False
# 1874            False               False              False         False
# 1897             True               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 49        False          True           False        False            False
# 55        False          True           False        False            False
# 146       False         False           False        False            False
# 160       False         False           False        False            False
# 197       False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1845      False         False           False        False            False
# 1849      False          True           False        False            False
# 1857      False         False           False        False             True
# 1874      False         False           False        False            False
# 1897      False          True           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 49           False     False        True         True       False  False
# 55           False      True        True         True       False  False
# 146          False      True        True         True       False  False
# 160          False      True        True         True       False  False
# 197          False     False        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1845         False      True        True         True       False  False
# 1849         False     False        True         True       False  False
# 1857         False     False        True         True       False  False
# 1874         False      True        True         True       False  False
# 1897         False      True        True         True       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 49              False             False          False           False
# 55              False              True           True           False
# 146             False              True          False           False
# 160             False             False          False           False
# 197             False             False          False           False
# ...               ...               ...            ...             ...
# 1845            False             False          False           False
# 1849            False             False          False           False
# 1857            False             False          False           False
# 1874            False              True          False            True
# 1897            False             False          False            True
#
# [90 rows x 38 columns]

# %%
data >> filter_by( (X.quality != 'Low') )
# Out:
#            id                       neighborhood   latitude  longitude  \
# 0     5528049                      Palm Jumeirah  25.000000  55.138932
# 1     6008529                      Palm Jumeirah  25.106809  55.151201
# 2     6034542               Jumeirah Lake Towers  25.063302  55.137728
# 4     6356778                      Palm Jumeirah  25.114275  55.139764
# 5     6356784                      Palm Jumeirah  25.114275  55.139764
# ...       ...                                ...        ...        ...
# 1900  7705450           Mohammed Bin Rashid City  25.176892  55.310712
# 1901  7706287           Mohammed Bin Rashid City  25.166145  55.276684
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  25.206500  55.345056
# 1903  7706591            Jumeirah Village Circle  25.073858  55.229844
# 1904  7706643               Jumeirah Lake Towers  25.079130  55.154713
#
#         price  size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  \
# 0     2700000          1079         2502.32               1                2
# 1     2850000          1582         1801.52               2                2
# 2     1150000          1951          589.44               3                5
# 4     1729200           507         3410.65               0                1
# 5     3119900          1015         3073.79               1                2
# ...       ...           ...             ...             ...              ...
# 1900  1500000          1087         1379.94               2                2
# 1901  1230000           760         1618.42               1                2
# 1902  2900000          1930         1502.59               3                5
# 1903   675000           740          912.16               1                2
# 1904   760887           800          951.11               1                2
#
#      quality  maid_room  unfurnished  balcony  barbecue_area  \
# 0     Medium      False        False     True           True
# 1     Medium      False        False     True          False
# 2     Medium       True         True     True          False
# 4     Medium      False        False    False          False
# 5     Medium      False        False    False          False
# ...      ...        ...          ...      ...            ...
# 1900   Ultra      False         True     True           True
# 1901  Medium      False        False     True          False
# 1902  Medium       True         True     True          False
# 1903  Medium      False         True     True          False
# 1904    High      False        False     True           True
#
#       built_in_wardrobes  central_ac  childrens_play_area  childrens_pool  \
# 0                  False        True                 True           False
# 1                   True        True                 True           False
# 2                   True       False                False           False
# 4                   True        True                False           False
# 5                   True        True                False           False
# ...                  ...         ...                  ...             ...
# 1900                True        True                 True            True
# 1901                True        True                 True           False
# 1902               False        True                 True           False
# 1903                True        True                 True           False
# 1904                True        True                 True            True
#
#       concierge  covered_parking  kitchen_appliances  lobby_in_building  \
# 0          True            False                True              False
# 1         False            False               False              False
# 2         False             True               False              False
# 4         False             True                True              False
# 5         False             True                True              False
# ...         ...              ...                 ...                ...
# 1900       True             True                True               True
# 1901       True            False                True              False
# 1902      False            False               False              False
# 1903      False             True                True              False
# 1904       True             True                True               True
#
#       maid_service  networked  pets_allowed  private_garden  private_gym  \
# 0            False      False          True           False        False
# 1            False      False         False           False        False
# 2            False      False         False           False        False
# 4            False       True         False           False        False
# 5            False       True         False           False        False
# ...            ...        ...           ...             ...          ...
# 1900          True       True          True           False        False
# 1901         False      False         False           False        False
# 1902         False      False          True           False        False
# 1903         False      False         False            True        False
# 1904         False      False         False           False        False
#
#       private_jacuzzi  private_pool  security  shared_gym  shared_pool  \
# 0               False         False     False        True        False
# 1               False         False     False        True         True
# 2                True         False      True        True         True
# 4               False         False      True        True         True
# 5               False         False      True        True         True
# ...               ...           ...       ...         ...          ...
# 1900            False         False      True        True         True
# 1901            False         False     False        True         True
# 1902            False         False     False       False         True
# 1903            False         False      True        True         True
# 1904            False         False      True        True         True
#
#       shared_spa  study  vastu_compliant  view_of_landmark  view_of_water  \
# 0          False  False            False             False           True
# 1          False  False            False             False           True
# 2          False  False            False              True           True
# 4           True  False            False              True           True
# 5           True  False            False              True           True
# ...          ...    ...              ...               ...            ...
# 1900        True   True             True              True           True
# 1901       False  False            False             False           True
# 1902       False  False            False             False          False
# 1903       False  False            False             False           True
# 1904        True  False            False             False           True
#
#       walk_in_closet
# 0              False
# 1              False
# 2               True
# 4              False
# 5              False
# ...              ...
# 1900            True
# 1901            True
# 1902           False
# 1903            True
# 1904           False
#
# [1361 rows x 38 columns]

# %%
data >> filter_by( ~ (X.price > 500000) )
# Out:
#            id               neighborhood   latitude  longitude   price  \
# 49    7033393                DAMAC Hills  25.016736  55.251010  365000
# 55    7075159       Jumeirah Lake Towers  25.065736  55.137452  375000
# 146   7346962          Dubai Sports City  25.044572  55.218948  390000
# 160   7376067          Dubai Sports City  25.042264  55.217360  410000
# 194   7414649  Jumeirah Village Triangle  25.043352  55.193510  310000
# ...       ...                        ...        ...        ...     ...
# 1848  7700652    Dubai Residence Complex  25.091311  55.378277  270000
# 1849  7700952       Jumeirah Lake Towers  25.071246  55.140806  499000
# 1857  7701727       Jumeirah Lake Towers  25.078148  55.148277  400888
# 1874  7702410                Town Square  25.003730  55.297034  488888
# 1897  7705293                    Al Quoz  25.153080  55.254242  360000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 49             451          809.31               0                1  Medium
# 55             450          833.33               0                1  Medium
# 146            849          459.36               1                2  Medium
# 160            969          423.12               1                2  Medium
# 194            425          729.41               0                1     Low
# ...            ...             ...             ...              ...     ...
# 1848           460          586.96               0                1     Low
# 1849           672          742.56               1                1  Medium
# 1857           403          994.76               0                1  Medium
# 1874           698          700.41               1                2  Medium
# 1897           600          600.00               0                1  Medium
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 49        False         True     True          False                True
# 55        False         True     True          False                True
# 146       False        False     True          False                True
# 160       False         True     True          False                True
# 194       False         True     True          False                True
# ...         ...          ...      ...            ...                 ...
# 1848      False         True     True          False                True
# 1849      False         True     True          False                True
# 1857      False        False     True           True                True
# 1874      False         True     True          False                True
# 1897      False        False     True          False               False
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 49          True                False           False      False
# 55          True                False           False      False
# 146         True                False           False      False
# 160         True                False           False       True
# 194        False                False           False      False
# ...          ...                  ...             ...        ...
# 1848       False                False           False      False
# 1849        True                False           False      False
# 1857        True                 True           False       True
# 1874        True                 True           False      False
# 1897        True                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 49               True               False              False         False
# 55               True               False              False         False
# 146              True                True              False         False
# 160             False                True              False         False
# 194              True               False              False         False
# ...               ...                 ...                ...           ...
# 1848             True               False              False         False
# 1849             True               False              False         False
# 1857             True                True              False         False
# 1874            False               False              False         False
# 1897             True               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 49        False          True           False        False            False
# 55        False          True           False        False            False
# 146       False         False           False        False            False
# 160       False         False           False        False            False
# 194       False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1848      False         False           False        False            False
# 1849      False          True           False        False            False
# 1857      False         False           False        False             True
# 1874      False         False           False        False            False
# 1897      False          True           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 49           False     False        True         True       False  False
# 55           False      True        True         True       False  False
# 146          False      True        True         True       False  False
# 160          False      True        True         True       False  False
# 194          False     False       False        False       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1848         False     False        True         True       False  False
# 1849         False     False        True         True       False  False
# 1857         False     False        True         True       False  False
# 1874         False      True        True         True       False  False
# 1897         False      True        True         True       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 49              False             False          False           False
# 55              False              True           True           False
# 146             False              True          False           False
# 160             False             False          False           False
# 194             False             False          False           False
# ...               ...               ...            ...             ...
# 1848            False             False          False           False
# 1849            False             False          False           False
# 1857            False             False          False           False
# 1874            False              True          False            True
# 1897            False             False          False            True
#
# [123 rows x 38 columns]

# %% [markdown]
# ## Mutate <a class="anchor" id="5"></a>

# %% [markdown]
# We can add a new variable to the data-set as follows:

# %%
data >> mutate(new_variable=X.price/1000) >> select(X.price , X.new_variable)
# Out:
#         price  new_variable
# 0     2700000      2700.000
# 1     2850000      2850.000
# 2     1150000      1150.000
# 3     2850000      2850.000
# 4     1729200      1729.200
# ...       ...           ...
# 1900  1500000      1500.000
# 1901  1230000      1230.000
# 1902  2900000      2900.000
# 1903   675000       675.000
# 1904   760887       760.887
#
# [1905 rows x 2 columns]

# %%
y = np.random.random_integers(0,50, size=len(data))

data >> mutate(new_variable = y) >> select(X.price , X.quality , X.new_variable)
# Out:
#         price quality  new_variable
# 0     2700000  Medium            49
# 1     2850000  Medium            14
# 2     1150000  Medium            31
# 3     2850000     Low             4
# 4     1729200  Medium            28
# ...       ...     ...           ...
# 1900  1500000   Ultra            28
# 1901  1230000  Medium            14
# 1902  2900000  Medium            33
# 1903   675000  Medium            18
# 1904   760887    High            35
#
# [1905 rows x 3 columns]

# %% [markdown]
# We can also add more than one variable at the same time:

# %%
y = np.random.random_integers(0 , 50 , size=len(data))

( data >> mutate(new_1 = y , new_2 = X.price/1000) >> 
          select(X.price , X.new_1 , X.new_2) )
# Out:
#         price  new_1     new_2
# 0     2700000     27  2700.000
# 1     2850000     13  2850.000
# 2     1150000     41  1150.000
# 3     2850000      9  2850.000
# 4     1729200      7  1729.200
# ...       ...    ...       ...
# 1900  1500000     29  1500.000
# 1901  1230000     42  1230.000
# 1902  2900000      7  2900.000
# 1903   675000      3   675.000
# 1904   760887     21   760.887
#
# [1905 rows x 3 columns]

# %% [markdown]
# `transmute` is the same as `mutate` but with the difference that `transmute`select only the new variables that have been added.

# %%
data >> transmute(new_1 = y , new_2 = X.price/1000)
# Out:
#       new_1     new_2
# 0        27  2700.000
# 1        13  2850.000
# 2        41  1150.000
# 3         9  2850.000
# 4         7  1729.200
# ...     ...       ...
# 1900     29  1500.000
# 1901     42  1230.000
# 1902      7  2900.000
# 1903      3   675.000
# 1904     21   760.887
#
# [1905 rows x 2 columns]

# %% [markdown]
# ## Arrange <a class="anchor" id="6"></a>

# %% [markdown]
# We can order the rows respect to one variable (column) as follows:

# %%
data >> arrange(X.price, ascending=True)
# Out:
#            id                  neighborhood   latitude  longitude     price  \
# 1592  7683016            International City  25.173301  55.402315    220000
# 1610  7684626  Dubai Production City (IMPZ)  25.036803  55.200909    230000
# 1609  7684618  Dubai Production City (IMPZ)  25.036803  55.200909    230000
# 749   7607826           Dubai Silicon Oasis  25.115934  55.390236    245000
# 1499  7675284           Dubai Silicon Oasis  25.115934  55.390236    250000
# ...       ...                           ...        ...        ...       ...
# 427   7545873                  Business Bay  25.188299  55.288975  30950000
# 1885  7703691                 Palm Jumeirah  25.103972  55.149621  31440000
# 576   7586332                 Palm Jumeirah  25.103550  55.168509  34314000
# 1869  7702221                 Palm Jumeirah  25.103972  55.149621  34340000
# 989   7636368                 Palm Jumeirah  25.103550  55.168509  35000000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 1592           484          454.55               0                1     Low
# 1610           380          605.26               0                1  Medium
# 1609           362          635.36               0                1  Medium
# 749            306          800.65               0                1     Low
# 1499           353          708.22               0                1     Low
# ...            ...             ...             ...              ...     ...
# 427           7922         3906.84               4                4  Medium
# 1885          6542         4805.87               4                6    High
# 576           9576         3583.33               4                5  Medium
# 1869          8722         3937.17               4                6    High
# 989           7346         4764.50               4                5     Low
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 1592      False         True     True          False               False
# 1610      False        False     True          False                True
# 1609      False         True     True          False                True
# 749       False        False    False          False               False
# 1499      False         True    False          False               False
# ...         ...          ...      ...            ...                 ...
# 427       False         True    False          False                True
# 1885       True        False     True          False               False
# 576       False         True     True          False                True
# 1869       True        False     True          False               False
# 989       False         True     True          False                True
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 1592        True                False           False      False
# 1610        True                 True           False      False
# 1609        True                 True           False      False
# 749        False                False           False      False
# 1499        True                False           False      False
# ...          ...                  ...             ...        ...
# 427         True                False           False      False
# 1885        True                False           False       True
# 576         True                False           False       True
# 1869        True                False           False       True
# 989        False                False           False       True
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 1592            False               False              False         False
# 1610            False               False              False         False
# 1609            False               False              False         False
# 749             False               False              False         False
# 1499            False               False               True         False
# ...               ...                 ...                ...           ...
# 427              True               False              False         False
# 1885             True                True              False          True
# 576              True                True              False         False
# 1869             True                True              False          True
# 989              True               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 1592      False          True           False        False            False
# 1610      False          True           False        False            False
# 1609      False          True           False        False            False
# 749       False         False           False        False            False
# 1499      False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 427       False         False           False        False            False
# 1885      False          True           False        False             True
# 576       False         False           False        False            False
# 1869      False          True            True        False             True
# 989       False         False           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 1592         False      True       False        False       False  False
# 1610         False     False        True         True       False  False
# 1609         False     False        True         True       False  False
# 749          False     False       False        False       False  False
# 1499         False      True        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 427          False     False        True         True       False  False
# 1885          True      True        True         True        True  False
# 576           True     False       False        False       False  False
# 1869          True      True        True         True        True  False
# 989           True     False       False        False       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 1592            False             False          False            True
# 1610            False             False           True           False
# 1609            False             False           True           False
# 749             False             False          False           False
# 1499            False             False          False           False
# ...               ...               ...            ...             ...
# 427             False              True          False           False
# 1885            False              True           True            True
# 576             False             False          False           False
# 1869            False              True           True            True
# 989             False             False          False           False
#
# [1905 rows x 38 columns]

# %%
data >> arrange(X.price, ascending=False)
# Out:
#            id                  neighborhood   latitude  longitude     price  \
# 989   7636368                 Palm Jumeirah  25.103550  55.168509  35000000
# 1869  7702221                 Palm Jumeirah  25.103972  55.149621  34340000
# 576   7586332                 Palm Jumeirah  25.103550  55.168509  34314000
# 1885  7703691                 Palm Jumeirah  25.103972  55.149621  31440000
# 427   7545873                  Business Bay  25.188299  55.288975  30950000
# ...       ...                           ...        ...        ...       ...
# 1499  7675284           Dubai Silicon Oasis  25.115934  55.390236    250000
# 749   7607826           Dubai Silicon Oasis  25.115934  55.390236    245000
# 1609  7684618  Dubai Production City (IMPZ)  25.036803  55.200909    230000
# 1610  7684626  Dubai Production City (IMPZ)  25.036803  55.200909    230000
# 1592  7683016            International City  25.173301  55.402315    220000
#
#       size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms quality  \
# 989           7346         4764.50               4                5     Low
# 1869          8722         3937.17               4                6    High
# 576           9576         3583.33               4                5  Medium
# 1885          6542         4805.87               4                6    High
# 427           7922         3906.84               4                4  Medium
# ...            ...             ...             ...              ...     ...
# 1499           353          708.22               0                1     Low
# 749            306          800.65               0                1     Low
# 1609           362          635.36               0                1  Medium
# 1610           380          605.26               0                1  Medium
# 1592           484          454.55               0                1     Low
#
#       maid_room  unfurnished  balcony  barbecue_area  built_in_wardrobes  \
# 989       False         True     True          False                True
# 1869       True        False     True          False               False
# 576       False         True     True          False                True
# 1885       True        False     True          False               False
# 427       False         True    False          False                True
# ...         ...          ...      ...            ...                 ...
# 1499      False         True    False          False               False
# 749       False        False    False          False               False
# 1609      False         True     True          False                True
# 1610      False        False     True          False                True
# 1592      False         True     True          False               False
#
#       central_ac  childrens_play_area  childrens_pool  concierge  \
# 989        False                False           False       True
# 1869        True                False           False       True
# 576         True                False           False       True
# 1885        True                False           False       True
# 427         True                False           False      False
# ...          ...                  ...             ...        ...
# 1499        True                False           False      False
# 749        False                False           False      False
# 1609        True                 True           False      False
# 1610        True                 True           False      False
# 1592        True                False           False      False
#
#       covered_parking  kitchen_appliances  lobby_in_building  maid_service  \
# 989              True               False              False         False
# 1869             True                True              False          True
# 576              True                True              False         False
# 1885             True                True              False          True
# 427              True               False              False         False
# ...               ...                 ...                ...           ...
# 1499            False               False               True         False
# 749             False               False              False         False
# 1609            False               False              False         False
# 1610            False               False              False         False
# 1592            False               False              False         False
#
#       networked  pets_allowed  private_garden  private_gym  private_jacuzzi  \
# 989       False         False           False        False            False
# 1869      False          True            True        False             True
# 576       False         False           False        False            False
# 1885      False          True           False        False             True
# 427       False         False           False        False            False
# ...         ...           ...             ...          ...              ...
# 1499      False         False           False        False            False
# 749       False         False           False        False            False
# 1609      False          True           False        False            False
# 1610      False          True           False        False            False
# 1592      False          True           False        False            False
#
#       private_pool  security  shared_gym  shared_pool  shared_spa  study  \
# 989           True     False       False        False       False  False
# 1869          True      True        True         True        True  False
# 576           True     False       False        False       False  False
# 1885          True      True        True         True        True  False
# 427          False     False        True         True       False  False
# ...            ...       ...         ...          ...         ...    ...
# 1499         False      True        True         True       False  False
# 749          False     False       False        False       False  False
# 1609         False     False        True         True       False  False
# 1610         False     False        True         True       False  False
# 1592         False      True       False        False       False  False
#
#       vastu_compliant  view_of_landmark  view_of_water  walk_in_closet
# 989             False             False          False           False
# 1869            False              True           True            True
# 576             False             False          False           False
# 1885            False              True           True            True
# 427             False              True          False           False
# ...               ...               ...            ...             ...
# 1499            False             False          False           False
# 749             False             False          False           False
# 1609            False             False           True           False
# 1610            False             False           True           False
# 1592            False             False          False            True
#
# [1905 rows x 38 columns]

# %% [markdown]
# ## Rename <a class="anchor" id="7"></a>

# %% [markdown]
# We can rename the names of variables as follows:

# %%
data >> rename(Name1=X.id, Name2=X.price)
# Out:
#         Name1                       neighborhood   latitude  longitude  \
# 0     5528049                      Palm Jumeirah  25.000000  55.138932
# 1     6008529                      Palm Jumeirah  25.106809  55.151201
# 2     6034542               Jumeirah Lake Towers  25.063302  55.137728
# 3     6326063                    Culture Village  25.227295  55.341761
# 4     6356778                      Palm Jumeirah  25.114275  55.139764
# ...       ...                                ...        ...        ...
# 1900  7705450           Mohammed Bin Rashid City  25.176892  55.310712
# 1901  7706287           Mohammed Bin Rashid City  25.166145  55.276684
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  25.206500  55.345056
# 1903  7706591            Jumeirah Village Circle  25.073858  55.229844
# 1904  7706643               Jumeirah Lake Towers  25.079130  55.154713
#
#         Name2  size_in_sqft  price_per_sqft  no_of_bedrooms  no_of_bathrooms  \
# 0     2700000          1079         2502.32               1                2
# 1     2850000          1582         1801.52               2                2
# 2     1150000          1951          589.44               3                5
# 3     2850000          2020         1410.89               2                3
# 4     1729200           507         3410.65               0                1
# ...       ...           ...             ...             ...              ...
# 1900  1500000          1087         1379.94               2                2
# 1901  1230000           760         1618.42               1                2
# 1902  2900000          1930         1502.59               3                5
# 1903   675000           740          912.16               1                2
# 1904   760887           800          951.11               1                2
#
#      quality  maid_room  unfurnished  balcony  barbecue_area  \
# 0     Medium      False        False     True           True
# 1     Medium      False        False     True          False
# 2     Medium       True         True     True          False
# 3        Low      False         True     True          False
# 4     Medium      False        False    False          False
# ...      ...        ...          ...      ...            ...
# 1900   Ultra      False         True     True           True
# 1901  Medium      False        False     True          False
# 1902  Medium       True         True     True          False
# 1903  Medium      False         True     True          False
# 1904    High      False        False     True           True
#
#       built_in_wardrobes  central_ac  childrens_play_area  childrens_pool  \
# 0                  False        True                 True           False
# 1                   True        True                 True           False
# 2                   True       False                False           False
# 3                  False       False                False           False
# 4                   True        True                False           False
# ...                  ...         ...                  ...             ...
# 1900                True        True                 True            True
# 1901                True        True                 True           False
# 1902               False        True                 True           False
# 1903                True        True                 True           False
# 1904                True        True                 True            True
#
#       concierge  covered_parking  kitchen_appliances  lobby_in_building  \
# 0          True            False                True              False
# 1         False            False               False              False
# 2         False             True               False              False
# 3          True             True               False              False
# 4         False             True                True              False
# ...         ...              ...                 ...                ...
# 1900       True             True                True               True
# 1901       True            False                True              False
# 1902      False            False               False              False
# 1903      False             True                True              False
# 1904       True             True                True               True
#
#       maid_service  networked  pets_allowed  private_garden  private_gym  \
# 0            False      False          True           False        False
# 1            False      False         False           False        False
# 2            False      False         False           False        False
# 3            False      False          True           False        False
# 4            False       True         False           False        False
# ...            ...        ...           ...             ...          ...
# 1900          True       True          True           False        False
# 1901         False      False         False           False        False
# 1902         False      False          True           False        False
# 1903         False      False         False            True        False
# 1904         False      False         False           False        False
#
#       private_jacuzzi  private_pool  security  shared_gym  shared_pool  \
# 0               False         False     False        True        False
# 1               False         False     False        True         True
# 2                True         False      True        True         True
# 3               False         False     False       False        False
# 4               False         False      True        True         True
# ...               ...           ...       ...         ...          ...
# 1900            False         False      True        True         True
# 1901            False         False     False        True         True
# 1902            False         False     False       False         True
# 1903            False         False      True        True         True
# 1904            False         False      True        True         True
#
#       shared_spa  study  vastu_compliant  view_of_landmark  view_of_water  \
# 0          False  False            False             False           True
# 1          False  False            False             False           True
# 2          False  False            False              True           True
# 3          False  False            False             False          False
# 4           True  False            False              True           True
# ...          ...    ...              ...               ...            ...
# 1900        True   True             True              True           True
# 1901       False  False            False             False           True
# 1902       False  False            False             False          False
# 1903       False  False            False             False           True
# 1904        True  False            False             False           True
#
#       walk_in_closet
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
# ...              ...
# 1900            True
# 1901            True
# 1902           False
# 1903            True
# 1904           False
#
# [1905 rows x 38 columns]

# %% [markdown]
# ## Gather <a class="anchor" id="8"></a>

# %%
( data >> gather('variable', 'value', ['price', 'quality']) >> 
select(X.size_in_sqft , X.no_of_bedrooms, X.variable, X.value) )
# Out:
#       size_in_sqft  no_of_bedrooms variable    value
# 0             1079               1    price  2700000
# 1             1582               2    price  2850000
# 2             1951               3    price  1150000
# 3             2020               2    price  2850000
# 4              507               0    price  1729200
# ...            ...             ...      ...      ...
# 3805          1087               2  quality    Ultra
# 3806           760               1  quality   Medium
# 3807          1930               3  quality   Medium
# 3808           740               1  quality   Medium
# 3809           800               1  quality     High
#
# [3810 rows x 4 columns]

# %%
data >> gather('variable', 'value')
# Out:
#              variable    value
# 0                  id  5528049
# 1                  id  6008529
# 2                  id  6034542
# 3                  id  6326063
# 4                  id  6356778
# ...               ...      ...
# 72385  walk_in_closet     True
# 72386  walk_in_closet     True
# 72387  walk_in_closet    False
# 72388  walk_in_closet     True
# 72389  walk_in_closet    False
#
# [72390 rows x 2 columns]

# %%
data_long = data >> gather('variable', 'value', ['price', 'quality'] ,  add_id=True ) >> select(X._ID , X.size_in_sqft , X.no_of_bedrooms, X.variable, X.value) 
# add_id=True is needed 
data_long
# Out:
#        _ID  size_in_sqft  no_of_bedrooms variable    value
# 0        0          1079               1    price  2700000
# 1        1          1582               2    price  2850000
# 2        2          1951               3    price  1150000
# 3        3          2020               2    price  2850000
# 4        4           507               0    price  1729200
# ...    ...           ...             ...      ...      ...
# 3805  1900          1087               2  quality    Ultra
# 3806  1901           760               1  quality   Medium
# 3807  1902          1930               3  quality   Medium
# 3808  1903           740               1  quality   Medium
# 3809  1904           800               1  quality     High
#
# [3810 rows x 5 columns]

# %% [markdown]
# ## Spread <a class="anchor" id="9"></a>

# %%
data_long >> spread(X.variable, X.value)
# Out:
#        _ID  size_in_sqft  no_of_bedrooms    price quality
# 0        0          1079               1  2700000  Medium
# 1        1          1582               2  2850000  Medium
# 2        2          1951               3  1150000  Medium
# 3        3          2020               2  2850000     Low
# 4        4           507               0  1729200  Medium
# ...    ...           ...             ...      ...     ...
# 1900  1900          1087               2  1500000   Ultra
# 1901  1901           760               1  1230000  Medium
# 1902  1902          1930               3  2900000  Medium
# 1903  1903           740               1   675000  Medium
# 1904  1904           800               1   760887    High
#
# [1905 rows x 5 columns]

# %% [markdown]
# We can separate and unite the data-set columns:

# %%
X1 = pd.Series([ "Femenino" , "Masculino", "Masculino", "Femenino" ])
X2 = pd.Series([ 12, 32, 30, -13])
X3 = pd.Series([  '1-a-3' , '1-b', '1-c-3-4', '9-d-1', '10' ])
X4 = pd.Series([ 22, 5, -30, 23])

df = pd.DataFrame( {"Sex": X1 , "X2": X2 , "X3": X3 , "X4": X4} )
df
# Out:
#          Sex    X2       X3    X4
# 0   Femenino  12.0    1-a-3  22.0
# 1  Masculino  32.0      1-b   5.0
# 2  Masculino  30.0  1-c-3-4 -30.0
# 3   Femenino -13.0    9-d-1  23.0
# 4        NaN   NaN       10   NaN

# %% [markdown]
# ## Separate <a class="anchor" id="10"></a>

# %% [markdown]
# Separate one column in several columns:

# %%
df >> separate(X.X3, ['col1', 'col2'], remove=True, convert=True,
                                       extra='drop', fill='right')
# Out:
#          Sex    X2    X4  col1 col2
# 0   Femenino  12.0  22.0     1    a
# 1  Masculino  32.0   5.0     1    b
# 2  Masculino  30.0 -30.0     1    c
# 3   Femenino -13.0  23.0     9    d
# 4        NaN   NaN   NaN    10  NaN

# %%
df >> separate(X.X3, ['col1', 'col2', 'col3', 'col4'], remove=True, convert=True,
                                                     extra='drop', fill='right')
# Out:
#          Sex    X2    X4  col1 col2  col3  col4
# 0   Femenino  12.0  22.0     1    a   3.0   NaN
# 1  Masculino  32.0   5.0     1    b   NaN   NaN
# 2  Masculino  30.0 -30.0     1    c   3.0   4.0
# 3   Femenino -13.0  23.0     9    d   1.0   NaN
# 4        NaN   NaN   NaN    10  NaN   NaN   NaN

# %%
df >> separate(X.X3, ['col1', 'col2', 'col3', 'col4'], remove=True, convert=True,
                                                       extra='drop', fill='left')
# Out:
#          Sex    X2    X4  col1 col2 col3 col4
# 0   Femenino  12.0  22.0   NaN    1    a    3
# 1  Masculino  32.0   5.0   NaN  NaN    1    b
# 2  Masculino  30.0 -30.0   1.0    c    3    4
# 3   Femenino -13.0  23.0   NaN    9    d    1
# 4        NaN   NaN   NaN   NaN  NaN  NaN   10

# %%
df >> separate(X.X3, ['col1', 'col2', 'col3', 'col4'], remove=False, convert=True,
                                                       extra='drop', fill='left')
# Out:
#          Sex    X2       X3    X4  col1 col2 col3 col4
# 0   Femenino  12.0    1-a-3  22.0   NaN    1    a    3
# 1  Masculino  32.0      1-b   5.0   NaN  NaN    1    b
# 2  Masculino  30.0  1-c-3-4 -30.0   1.0    c    3    4
# 3   Femenino -13.0    9-d-1  23.0   NaN    9    d    1
# 4        NaN   NaN       10   NaN   NaN  NaN  NaN   10

# %%
df >> separate(X.X3, ['col1', 'col2', 'col3', 'col4'], sep=[1,4] ,
               remove=False, convert=True,
               extra='drop', fill='left')
# Out:
#          Sex    X2       X3    X4  col1 col2 col3  col4
# 0   Femenino  12.0    1-a-3  22.0     1  -a-    3   NaN
# 1  Masculino  32.0      1-b   5.0     1   -b  NaN   NaN
# 2  Masculino  30.0  1-c-3-4 -30.0     1  -c-  3-4   NaN
# 3   Femenino -13.0    9-d-1  23.0     9  -d-    1   NaN
# 4        NaN   NaN       10   NaN     1    0  NaN   NaN

# %%
from numpy import NaN

X1 = pd.Series([ "Femenino" , "Masculino", "Masculino", "Femenino" ])
X2 = pd.Series([ 12, 32, 30, -13])
X3 = pd.Series([  'a-3' , '+b', 10, NaN ])
X4 = pd.Series([ 22, 5, -30, 23])

df = pd.DataFrame( {"Sex": X1 , "X2": X2 , "X3": X3 , "X4": X4} )
df
# Out:
#          Sex  X2   X3  X4
# 0   Femenino  12  a-3  22
# 1  Masculino  32   +b   5
# 2  Masculino  30   10 -30
# 3   Femenino -13  NaN  23

# %% [markdown]
# ## Unite <a class="anchor" id="11"></a>

# %% [markdown]
# Unite several columns in one column:

# %%
df >> unite('united',  ['X3', 'X4'], remove=False, na_action='maintain')
# Out:
# ['X3', 'X4'] _ False maintain
#          Sex  X2   X3  X4  united
# 0   Femenino  12  a-3  22  a-3_22
# 1  Masculino  32   +b   5    +b_5
# 2  Masculino  30   10 -30  10_-30
# 3   Femenino -13  NaN  23     NaN

# %%
df >> unite('united',  ['X3', 'X4'], remove=False, na_action='as_string')
# Out:
# ['X3', 'X4'] _ False as_string
#          Sex  X2   X3  X4  united
# 0   Femenino  12  a-3  22  a-3_22
# 1  Masculino  32   +b   5    +b_5
# 2  Masculino  30   10 -30  10_-30
# 3   Femenino -13  NaN  23  nan_23

# %%
df >> unite('united',  ['X3', 'X4'], remove=True, na_action='maintain')
# Out:
# ['X3', 'X4'] _ True maintain
#          Sex  X2  united
# 0   Femenino  12  a-3_22
# 1  Masculino  32    +b_5
# 2  Masculino  30  10_-30
# 3   Femenino -13     NaN

# %%
df >> unite('united',  ['X3', 'X4'], remove=False, na_action='maintain', sep='**')
# Out:
# ['X3', 'X4'] ** False maintain
#          Sex  X2   X3  X4   united
# 0   Femenino  12  a-3  22  a-3**22
# 1  Masculino  32   +b   5    +b**5
# 2  Masculino  30   10 -30  10**-30
# 3   Femenino -13  NaN  23      NaN

# %%
df >> unite('united',  ['X3', 'X4'], remove=False, na_action='maintain', sep='//')
# Out:
# ['X3', 'X4'] // False maintain
#          Sex  X2   X3  X4   united
# 0   Femenino  12  a-3  22  a-3//22
# 1  Masculino  32   +b   5    +b//5
# 2  Masculino  30   10 -30  10//-30
# 3   Femenino -13  NaN  23      NaN

# %% [markdown]
# ## Joins <a class="anchor" id="12"></a>

# %% [markdown]
# We can join data-sets as well:

# %%
Alumnos = pd.DataFrame({
        'Name':['Pepe','Juan','Eva', 'Rosa', 'Ricardo'],
        'DNI':['2234X', '3987Y', '5412U' , '7814J' , '2233K'],
        'Age': [15 , 17 , 16 , 13, 14 ]
    })

Repetidores = pd.DataFrame({
    'Name':['Pepe','Juan','Rosa'],
    'Final_Score':[5, 6, 7.5],
    'Repeater' : ['yes', 'yes', 'yes']
})

Deportistas = pd.DataFrame({
    'Name':['Eva','Juan'],
    'Sport':['Basket', 'Soccer'],
    'Sporty': ['true' , 'true']
})

# %%
Alumnos
# Out:
#       Name    DNI  Age
# 0     Pepe  2234X   15
# 1     Juan  3987Y   17
# 2      Eva  5412U   16
# 3     Rosa  7814J   13
# 4  Ricardo  2233K   14

# %%
Repetidores
# Out:
#    Name  Final_Score Repeater
# 0  Pepe          5.0      yes
# 1  Juan          6.0      yes
# 2  Rosa          7.5      yes

# %%
Deportistas
# Out:
#    Name   Sport Sporty
# 0   Eva  Basket   true
# 1  Juan  Soccer   true

# %% [markdown]
# ### Inner Join <a class="anchor" id="13"></a>

# %%
Alumnos >> inner_join(Repetidores, by='Name')
# Out:
#    Name    DNI  Age  Final_Score Repeater
# 0  Pepe  2234X   15          5.0      yes
# 1  Juan  3987Y   17          6.0      yes
# 2  Rosa  7814J   13          7.5      yes

# %% [markdown]
# ### Full Join <a class="anchor" id="14"></a>

# %%
Alumnos >> full_join(Repetidores, by='Name')
# Out:
#       Name    DNI  Age  Final_Score Repeater
# 0     Pepe  2234X   15          5.0      yes
# 1     Juan  3987Y   17          6.0      yes
# 2      Eva  5412U   16          NaN      NaN
# 3     Rosa  7814J   13          7.5      yes
# 4  Ricardo  2233K   14          NaN      NaN

# %% [markdown]
# ### Left Join <a class="anchor" id="15"></a>

# %%
Alumnos >>  left_join(Repetidores, by='Name')
# Out:
#       Name    DNI  Age  Final_Score Repeater
# 0     Pepe  2234X   15          5.0      yes
# 1     Juan  3987Y   17          6.0      yes
# 2      Eva  5412U   16          NaN      NaN
# 3     Rosa  7814J   13          7.5      yes
# 4  Ricardo  2233K   14          NaN      NaN

# %%
Deportistas >>  left_join(Repetidores, by='Name')
# Out:
#    Name   Sport Sporty  Final_Score Repeater
# 0   Eva  Basket   true          NaN      NaN
# 1  Juan  Soccer   true          6.0      yes

# %%
Repetidores >>  left_join(Deportistas, by='Name')
# Out:
#    Name  Final_Score Repeater   Sport Sporty
# 0  Pepe          5.0      yes     NaN    NaN
# 1  Juan          6.0      yes  Soccer   true
# 2  Rosa          7.5      yes     NaN    NaN

# %% [markdown]
# ### Right Join <a class="anchor" id="16"></a>

# %%
Deportistas >>  right_join(Repetidores, by='Name') 

# equivalent to Repetidores >>  left_join(Deportistas, by='Name')
# Out:
#    Name   Sport Sporty  Final_Score Repeater
# 0  Pepe     NaN    NaN          5.0      yes
# 1  Juan  Soccer   true          6.0      yes
# 2  Rosa     NaN    NaN          7.5      yes

# %%
Repetidores >>  right_join(Deportistas, by='Name') 

# equivalent to Deportistas >>  left_join(Repetidores, by='Name')
# Out:
#    Name  Final_Score Repeater   Sport Sporty
# 0   Eva          NaN      NaN  Basket   true
# 1  Juan          6.0      yes  Soccer   true

# %% [markdown]
# ### Semi Join <a class="anchor" id="17"></a>

# %%
Alumnos >>  semi_join(Repetidores, by='Name')
# Out:
#    Name    DNI  Age
# 0  Pepe  2234X   15
# 1  Juan  3987Y   17
# 2  Rosa  7814J   13

# %% [markdown]
# ### Anti Join <a class="anchor" id="18"></a>

# %%
Alumnos >>  anti_join(Repetidores, by='Name')
# Out:
#       Name    DNI  Age
# 2      Eva  5412U   16
# 4  Ricardo  2233K   14

# %%
df1 = pd.DataFrame({
        'X1':['A','B','C'],
        'X2':[55, 32, 63]
    })
df2 = pd.DataFrame({
      'X1':['B','C','D'],
      'X2':[32, 63, 74]
})

# %% [markdown]
# ### Union <a class="anchor" id="19"></a>

# %%
df1 >> union(df2)
# Out:
#   X1  X2
# 0  A  55
# 1  B  32
# 2  C  63
# 2  D  74

# %% [markdown]
# ### Intersect <a class="anchor" id="20"></a>

# %%
df1 >> intersect(df2)
# Out:
#   X1  X2
# 0  B  32
# 1  C  63

# %% [markdown]
# ### Difference <a class="anchor" id="21"></a>

# %%
df1 >>  set_diff(df2)
# Out:
#   X1  X2
# 0  A  55

# %%
df2 >>  set_diff(df1)
# Out:
#   X1  X2
# 2  D  74

# %% [markdown]
# ## Concatenate <a class="anchor" id="22"></a>

# %% [markdown]
# We can concatenate different data-set as follows:

# %%
df1 = pd.DataFrame({
        'X1':['A','B','C'],
        'X2':[55, 32, 63], 
        'X3': [0, 2, 5]
    })
df2 = pd.DataFrame({
      'X1':['B','C','D'],
      'X2':[32, 63, 74],
      'X4':[32, 63, 74]
})

# %%
df1
# Out:
#   X1  X2  X3
# 0  A  55   0
# 1  B  32   2
# 2  C  63   5

# %%
df2
# Out:
#   X1  X2  X4
# 0  B  32  32
# 1  C  63  63
# 2  D  74  74

# %% [markdown]
# Concatenate by rows:

# %%
df1 >> bind_rows(df2 , join='inner')
# Out:
#   X1  X2
# 0  A  55
# 1  B  32
# 2  C  63
# 0  B  32
# 1  C  63
# 2  D  74

# %%
df1 >> bind_rows(df2 , join='outer')
# Out:
#   X1  X2   X3    X4
# 0  A  55  0.0   NaN
# 1  B  32  2.0   NaN
# 2  C  63  5.0   NaN
# 0  B  32  NaN  32.0
# 1  C  63  NaN  63.0
# 2  D  74  NaN  74.0

# %%
df1 >> bind_rows(df2 , join='outer', ignore_index=True)
# Out:
#   X1  X2   X3    X4
# 0  A  55  0.0   NaN
# 1  B  32  2.0   NaN
# 2  C  63  5.0   NaN
# 3  B  32  NaN  32.0
# 4  C  63  NaN  63.0
# 5  D  74  NaN  74.0

# %% [markdown]
# Concatenate by columns:

# %%
df1 >> bind_cols(df2 , join='inner')
# Out:
#   X1  X2  X3 X1  X2  X4
# 0  A  55   0  B  32  32
# 1  B  32   2  C  63  63
# 2  C  63   5  D  74  74

# %%
df1 >> bind_cols(df2 , join='outer')
# Out:
#   X1  X2  X3 X1  X2  X4
# 0  A  55   0  B  32  32
# 1  B  32   2  C  63  63
# 2  C  63   5  D  74  74

# %% [markdown]
# ## Group and Summarize <a class="anchor" id="23"></a>

# %% [markdown]
# We can group and summarize as follows:

# %%
( round( data >> group_by('quality') >> 
summarize(price_mean=X.price.mean(), 
          price_median=X.price.median(), 
          price_std=X.price.std()) ) )
# Out:
#   quality  price_mean  price_median  price_std
# 0    High   2688829.0     1400103.0  4852033.0
# 1     Low   1937610.0     1465444.0  2307412.0
# 2  Medium   2168123.0     1470388.0  2947205.0
# 3   Ultra    919428.0      759502.0   395046.0

# %%
round( data >> group_by('quality') >> 
summarize(price_mean=X.price.mean(), 
          price_median=X.price.median(), price_var=X.price.var(), 
          price_std=X.price.std()  , price_max=X.price.max() ,  
          price_min=X.price.min(),   price_count=n(X.price) ,  
          price_count_distinct=n_distinct(X.price) , 
          price_IQR = IQR(X.price) ) )
# Out:
#   quality  price_mean  price_median     price_var  price_std  price_max  \
# 0    High   2688829.0     1400103.0  2.354223e+13  4852033.0   34340000
# 1     Low   1937610.0     1465444.0  5.324149e+12  2307412.0   35000000
# 2  Medium   2168123.0     1470388.0  8.686019e+12  2947205.0   34314000
# 3   Ultra    919428.0      759502.0  1.560616e+11   395046.0    2551888
#
#    price_min  price_count  price_count_distinct  price_IQR
# 0     360000          134                   113  1441842.0
# 1     220000          544                   299  1216250.0
# 2     230000         1146                   559  1389084.0
# 3     440500           81                    74   369300.0

# %% [markdown]
# Other useful function to filter observations (rows):

# %%
( data >> mutate(price_between = between(X.price , 500000 , 1000000)) >>
 select(X.price , X.price_between) )
# Out:
#         price  price_between
# 0     2700000          False
# 1     2850000          False
# 2     1150000          False
# 3     2850000          False
# 4     1729200          False
# ...       ...            ...
# 1900  1500000          False
# 1901  1230000          False
# 1902  2900000          False
# 1903   675000           True
# 1904   760887           True
#
# [1905 rows x 2 columns]

# %% [markdown]
# ## Other usuful functions <a class="anchor" id="24"></a>

# %%
( data >> mutate(price_dense_rank = dense_rank(X.price)) >> 
select(X.price , X.price_dense_rank) )
# Out:
#         price  price_dense_rank
# 0     2700000             645.0
# 1     2850000             651.0
# 2     1150000             341.0
# 3     2850000             651.0
# 4     1729200             503.0
# ...       ...               ...
# 1900  1500000             454.0
# 1901  1230000             360.0
# 1902  2900000             654.0
# 1903   675000             148.0
# 1904   760887             194.0
#
# [1905 rows x 2 columns]

# %%
( data >> mutate(price_cumsum = cumsum(X.price)) >> 
select(X.price , X.price_cumsum) )
# Out:
#         price  price_cumsum
# 0     2700000       2700000
# 1     2850000       5550000
# 2     1150000       6700000
# 3     2850000       9550000
# 4     1729200      11279200
# ...       ...           ...
# 1900  1500000    3967940022
# 1901  1230000    3969170022
# 1902  2900000    3972070022
# 1903   675000    3972745022
# 1904   760887    3973505909
#
# [1905 rows x 2 columns]

# %%
( data >> mutate(price_cummean = cummean(X.price)) >>
select(X.price , X.price_cummean) )
# Out:
#         price  price_cummean
# 0     2700000   2.700000e+06
# 1     2850000   2.775000e+06
# 2     1150000   2.233333e+06
# 3     2850000   2.387500e+06
# 4     1729200   2.255840e+06
# ...       ...            ...
# 1900  1500000   2.087291e+06
# 1901  1230000   2.086840e+06
# 1902  2900000   2.087267e+06
# 1903   675000   2.086526e+06
# 1904   760887   2.085830e+06
#
# [1905 rows x 2 columns]

# %%
(data >> mutate(price_cumprod = cumprod(X.price)) >>
 select(X.price , X.price_cumprod) )
# Out:
#         price        price_cumprod
# 0     2700000              2700000
# 1     2850000        7695000000000
# 2     1150000  8849250000000000000
# 3     2850000 -7550831625259843584
# 4     1729200  2556877478461177856
# ...       ...                  ...
# 1900  1500000                    0
# 1901  1230000                    0
# 1902  2900000                    0
# 1903   675000                    0
# 1904   760887                    0
#
# [1905 rows x 2 columns]

# %% [markdown]
# ## Bibliography

# %% [markdown]
#   Katovich, K. dfply. *GitHub repository*.  https://github.com/kieferk/dfply
